# %%
import uproot as up
import numpy as np
import awkward as ak
import mplhep as hep
hep.style.use(hep.style.CMS)
import ROOT
import matplotlib.pyplot as plt
from fit_types import fit_unbinned_double_gauss_Y, fit_unbinned_double_gauss_Z, fit_unbinned_gauss_with_background
# Out:
# Welcome to JupyROOT 6.26/10

# %%
# dataset = '../output/ZmmYee/Data/crab_TTree_13TeV_fourmuon_2018BCD_v5.root'
# savepath = 'plots/Data/cuts_v6/'
dataset = '../output/ZmmYee/MC/ZmmMCOut.root'
savepath = 'plots/MC/cuts_v6/'

# %%
# open the file
file = up.open(dataset)
events = file['ntuple;1']
columns = ['Event', 'Run', 'LumiBlock',
           'Mu_TriggerPath',
           'Z_soft1', 'Z_soft2',
           'Z_Vtx_Mass', 'Z_mass',
           'Z_pt1', 'Z_pt2', 'Z_eta1', 'Z_eta2',
           'Z_lowPt', 'Z_highPt',
           'Y_Vtx_Mass', 'Y_mass',
           'Y_pt1', 'Y_pt2', 'Y_eta1', 'Y_eta2',
           'Y_mvaIsoWP90_1', 'Y_mvaIsoWP90_2',
           'Z_Vtx_Prob', 'Y_Vtx_Prob',
           'FourL_mass', 'FourL_Vtx_Prob',
           'Y_lowPt', 'Y_highPt']
# branches = events.arrays(columns, entry_start=430, entry_stop=450)
branches = events.arrays(columns)

# %%
def print_summary(data, text):
    events = len(data)
    candidates = np.sum(ak.num(branches['Y_mass'], axis=1))

    print(f"Number of candidates {text}: {candidates}")
    print(f"Number of events {text}: {events}")

# %%
print_summary(branches, 'Preselection')
# Out:
# Number of candidates Preselection: 3511
# Number of events Preselection: 3330

# %%
print(ak.sum(branches.Y_pt1 > branches.Y_pt2))
print(ak.sum(branches.Z_pt1 > branches.Z_pt2))
print(ak.sum(branches.Z_lowPt < branches.Z_highPt))

# remove events with Z_pt1 < Z_pt2
cut_highLow_candi= (branches.Z_pt1 > branches.Z_pt2)
cut_highLow_events = ak.any(cut_highLow_candi, axis=1)

branches = branches[cut_highLow_candi][cut_highLow_events]

cut_highLow_candi_Y = (branches.Y_pt1 > branches.Y_pt2)
cut_highLow_events_Y = ak.any(cut_highLow_candi_Y, axis=1)

branches = branches[cut_highLow_candi_Y][cut_highLow_events_Y]

print_summary(branches, 'Z pt1 > Z pt2')
# Out:
# 3511
# 3511
# 3511
# Number of candidates Z pt1 > Z pt2: 3511
# Number of events Z pt1 > Z pt2: 3330

# %%
cut_YTrigger_candi = branches['Mu_TriggerPath']
cut_YTrigger_event = ak.any(cut_YTrigger_candi, axis=1)

branches = branches[cut_YTrigger_candi][cut_YTrigger_event]

print_summary(branches, "Trigger")
# Out:
# Number of candidates Trigger: 3275
# Number of events Trigger: 3111

# %%
cut_Zsoft_candi = branches['Z_soft1'] & branches['Z_soft2']
cut_Zsoft_event = ak.any(cut_Zsoft_candi, axis=1)

branches = branches[cut_Zsoft_candi][cut_Zsoft_event]

print_summary(branches, "Soft Muons")
# Out:
# Number of candidates Soft Muons: 3211
# Number of events Soft Muons: 3075

# %%
# events with hights pt muon > 24
cut_highPt24_candi = branches['Z_highPt'] > 24
cut_highPt24_event = ak.any(cut_highPt24_candi, axis=1)

branches = branches[cut_highPt24_candi][cut_highPt24_event]

print_summary(branches, "High Pt Muon")
# Out:
# Number of candidates High Pt Muon: 3207
# Number of events High Pt Muon: 3074

# %%
cut_dilepton_candi = (branches['Y_Vtx_Prob'] > 0.01) & (branches['Z_Vtx_Prob'] > 0.01)
cut_dilepton_event = ak.any(cut_dilepton_candi, axis=1)

plt.figure(figsize=(8, 8))
nbins, xlow, xhigh = 100, 0, 1
plt.hist(ak.flatten(branches.Y_Vtx_Prob), bins=nbins, label="Y", alpha=0.5)
plt.hist(ak.flatten(branches.Z_Vtx_Prob), bins=nbins, label="Z", alpha=0.5)
plt.axvline(x=0.01, color='r')
plt.xlabel('Dilepton Vtx Prob')
plt.ylabel(f"Counts / {(xhigh-xlow)/nbins:.2f}")
plt.legend()
plt.tight_layout()
plt.savefig(f"{savepath}/vtx_prob_dilepton.png")

branches = branches[cut_dilepton_candi][cut_dilepton_event]

print_summary(branches, "Dilepton Vtx")
# Out:
# Number of candidates Dilepton Vtx: 3065
# Number of events Dilepton Vtx: 2949

# %%
cut_FourL_candi = (branches['FourL_Vtx_Prob'] > 0.01)
cut_FourL_event = ak.any(cut_FourL_candi, axis=1)

plt.figure(figsize=(8, 8))
nbins, xlow, xhigh = 100, 0, 1
plt.hist(ak.flatten(branches.FourL_Vtx_Prob), bins=nbins, alpha=0.5)
plt.axvline(x=0.01, color='r')
plt.xlabel('FourL Vtx Prob')
plt.ylabel(f"Counts / {(xhigh-xlow)/nbins:.2f}")
plt.tight_layout()
plt.savefig(f"{savepath}/vtx_prob_fourL.png")

branches = branches[cut_FourL_candi][cut_FourL_event]

print_summary(branches, "FourL Vtx")
# Out:
# Number of candidates FourL Vtx: 2980
# Number of events FourL Vtx: 2872

# %%
cut_Pt_candi = (branches['Z_pt1'] > 3.0) & (branches['Z_pt2'] > 3.0) & (branches['Y_pt1'] > 5.0) & (branches['Y_pt2'] > 5.0)
cut_eta_candi = (abs(branches['Z_eta1']) < 2.4) & (abs(branches['Z_eta2']) < 2.4) & (abs(branches['Y_eta1']) < 2.5) & (abs(branches['Y_eta2']) < 2.5)
cut_detector_candi = cut_Pt_candi & cut_eta_candi
cut_detector_event = ak.any(cut_detector_candi, axis=1)

plt.figure(figsize=(8, 8))
nbins, xlow, xhigh = 75, 0, 150
plt.hist(ak.flatten(branches.Z_pt1), bins=nbins, label="Mu_pt1", range=(xlow, xhigh), alpha=0.5) #, histtype='step')
plt.hist(ak.flatten(branches.Z_pt2), bins=nbins, label="Mu_pt2", range=(xlow, xhigh), alpha=0.5) #, histtype='step')
plt.axvline(3.0, color='r')
plt.xlabel("Mu pT [GeV]")
plt.ylabel(f"Counts / {(xhigh-xlow)/nbins:.2f} GeV")
plt.legend()
plt.tight_layout()
plt.savefig(f"{savepath}/Mu_pt.png")

plt.figure(figsize=(8, 8))
nbins, xlow, xhigh = 50, 0, 50
plt.hist(ak.flatten(branches.Y_pt1), bins=nbins, label="Ele_pt1", range=(xlow, xhigh), alpha=0.5) #, histtype='step')
plt.hist(ak.flatten(branches.Y_pt2), bins=nbins, label="Ele_pt2", range=(xlow, xhigh), alpha=0.5) #, histtype='step')
plt.axvline(5.0, color='r')
plt.xlabel("Ele pT [GeV]")
plt.ylabel(f"Counts / {(xhigh-xlow)/nbins:.2f} GeV")
plt.legend()
plt.tight_layout()
plt.savefig(f"{savepath}/Ele_pt.png")

plt.figure(figsize=(8, 8))
nbins, xlow, xhigh = 30, 0, 3
plt.hist(ak.flatten(branches.Z_eta1), bins=nbins, label="Mu_eta1", range=(xlow, xhigh), alpha=0.5) #, histtype='step')
plt.hist(ak.flatten(branches.Z_eta2), bins=nbins, label="Mu_eta2", range=(xlow, xhigh), alpha=0.5) #, histtype='step')
plt.axvline(2.4, color='r')
plt.xlabel("Mu eta")
plt.ylabel(f"Counts / {(xhigh-xlow)/nbins:.2f}")
plt.legend()
plt.tight_layout()
plt.savefig(f"{savepath}/Mu_eta.png")

plt.figure(figsize=(8, 8))
nbins, xlow, xhigh = 30, 0, 3
plt.hist(ak.flatten(branches.Y_eta1), bins=nbins, label="Ele_eta1", range=(xlow, xhigh), alpha=0.5) #, histtype='step')
plt.hist(ak.flatten(branches.Y_eta2), bins=nbins, label="Ele_eta2", range=(xlow, xhigh), alpha=0.5) #, histtype='step')
plt.axvline(2.5, color='r')
plt.xlabel("Ele eta")
plt.ylabel(f"Counts / {(xhigh-xlow)/nbins:.2f}")
plt.legend()
plt.tight_layout()
plt.savefig(f"{savepath}/Ele_eta.png")

branches = branches[cut_detector_candi][cut_detector_event]

print_summary(branches, "Detector")
# Out:
# Number of candidates Detector: 2182
# Number of events Detector: 2155

# %%
plt.figure(figsize=(8, 8))
nbins, xlow, xhigh = 80, 5, 13

mean_Ymass = np.mean(ak.flatten(branches.Y_mass))
std_Ymass = np.std(ak.flatten(branches.Y_mass))
mean_Yvtxmass = np.mean(ak.flatten(branches.Y_Vtx_Mass))
std_Yvtxmass = np.std(ak.flatten(branches.Y_Vtx_Mass))

plt.hist(ak.flatten(branches.Y_Vtx_Mass), bins=nbins, label=f"diele_Vtx_Mass ({mean_Yvtxmass:.1f}+/-{std_Yvtxmass:.1f})", alpha=0.5, range=(xlow, xhigh))
plt.hist(ak.flatten(branches.Y_mass), bins=nbins, label=f"diele_mass ({mean_Ymass:.1f}+/-{std_Ymass:.1f})", alpha=0.5, range=(xlow, xhigh))

plt.legend(fontsize=12)
plt.xlabel('Dielectron inv mass (GeV)')
plt.ylabel(f"Counts / {(xhigh-xlow)/nbins:.2f} GeV")
plt.tight_layout()
plt.savefig(f"{savepath}/Vtx_vs_normal_mass_Y.png")

plt.figure(figsize=(8, 8))
nbins, xlow, xhigh = 50, 65, 115

mean_Zmass = np.mean(ak.flatten(branches.Z_mass))
std_Zmass = np.std(ak.flatten(branches.Z_mass))
mean_Zvtxmass = np.mean(ak.flatten(branches.Z_Vtx_Mass))
std_Zvtxmass = np.std(ak.flatten(branches.Z_Vtx_Mass))

plt.hist(ak.flatten(branches.Z_Vtx_Mass), bins=nbins, label=f"dimu_Vtx_Mass ({mean_Zvtxmass:.1f}+/-{std_Zvtxmass:.1f})", alpha=0.5, range=(xlow, xhigh))
plt.hist(ak.flatten(branches.Z_mass), bins=nbins, label=f"dimu_mass ({mean_Zmass:.1f}+/-{std_Zmass:.1f})", alpha=0.5, range=(xlow, xhigh))

plt.legend(fontsize=12)
plt.xlabel('Dimuon inv mass (GeV)')
plt.ylabel(f"Counts / {(xhigh-xlow)/nbins:.2f} GeV")
plt.tight_layout()
plt.savefig(f"{savepath}/Vtx_vs_normal_mass_Z.png")

# %%
eleID_cut_type = "both" # "low pT", "high pT", "both"

before_mass_cuts_Y = ak.flatten(branches['Y_mass'])
Hpt_before_mass_cuts_Y = ak.flatten(branches['Y_pt1'])
Lpt_before_mass_cuts_Y = ak.flatten(branches['Y_pt2'])

before_mass_cuts_Z = ak.flatten(branches['Z_mass'])
Hpt_before_mass_cuts_Z = ak.flatten(branches['Z_pt1'])
Lpt_before_mass_cuts_Z = ak.flatten(branches['Z_pt2'])

# %%
# cut_Ymass_candi = (branches['Y_mass'] > 8) & (branches['Y_mass'] < 10)
# cut_Ymass_event = ak.any(cut_Ymass_candi, axis=1)

# plt.figure(figsize=(8, 8))
# nbins, xlow, xhigh = 20, 2.8, 12
# plt.hist(ak.flatten(branches.Y_mass), bins=nbins, label="Y_mass", alpha=0.5, range=(xlow, xhigh))
# mean = np.mean(ak.flatten(branches.Y_mass))
# std = np.std(ak.flatten(branches.Y_mass))
# plt.text(0.75, 0.9, f"Mean: {mean:.2f}\nStd: {std:.2f}", transform=plt.gca().transAxes, fontsize=12)
# plt.text(0.75, 0.85, f"Events: {len(ak.flatten(branches.Y_mass))}", transform=plt.gca().transAxes, fontsize=12)
# plt.axvline(x=8, color='r')
# plt.axvline(x=10, color='r')
# plt.xlabel('Dielectron inv mass (GeV)')
# plt.ylabel(f"Counts / {(xhigh-xlow)/nbins:.2f} GeV")
# plt.tight_layout()
# plt.savefig(f"{savepath}/Y_mass_cut.png")

# branches = branches[cut_Ymass_candi][cut_Ymass_event]

# print_summary(branches, "Y mass")

# %%
cut_Zmass_candi = (branches['Z_mass'] > 70) & (branches['Z_mass'] < 110)
cut_Zmass_event = ak.any(cut_Zmass_candi, axis=1)

plt.figure(figsize=(8, 8))
nbins, xlow, xhigh = 20, 70, 110
plt.hist(ak.flatten(branches.Z_mass), bins=nbins, label="Z_mass", alpha=0.5, range=(xlow, xhigh))
mean = np.mean(ak.flatten(branches.Z_mass))
std = np.std(ak.flatten(branches.Z_mass))
plt.text(0.8, 0.9, f"Mean: {mean:.2f}\nStd: {std:.2f}", transform=plt.gca().transAxes, fontsize=12)
plt.text(0.8, 0.85, f"Events: {len(ak.flatten(branches.Z_mass))}", transform=plt.gca().transAxes, fontsize=12)
plt.xlabel('Dimuon inv Mass (GeV)')
plt.ylabel(f"Counts / {(xhigh-xlow)/nbins:.2f} GeV")
plt.tight_layout()
plt.savefig(f"{savepath}/Z_mass_cut.png")

branches = branches[cut_Zmass_candi][cut_Zmass_event]

print_summary(branches, "Z mass")
# Out:
# Number of candidates Z mass: 2182
# Number of events Z mass: 2155

# %%
before_ID_cuts_Y = ak.flatten(branches['Y_mass'])
Hpt_before_ID_cuts_Y = ak.flatten(branches['Y_pt1'])
Lpt_before_ID_cuts_Y = ak.flatten(branches['Y_pt2'])

before_ID_cuts_Z = ak.flatten(branches['Z_mass'])
Hpt_before_ID_cuts_Z = ak.flatten(branches['Z_pt1'])
Lpt_before_ID_cuts_Z = ak.flatten(branches['Z_pt2'])

if eleID_cut_type == "low pT":
    cut_YmvaIso_candi = branches['Y_mvaIsoWP90_2']
elif eleID_cut_type == "high pT":
    cut_YmvaIso_candi = branches['Y_mvaIsoWP90_1']
elif eleID_cut_type == "both":
    cut_YmvaIso_candi = branches['Y_mvaIsoWP90_1'] & branches['Y_mvaIsoWP90_2']
else:
    print("Invalid eleID_cut_type")

cut_YmvaIso_event = ak.any(cut_YmvaIso_candi, axis=1)

branches = branches[cut_YmvaIso_candi][cut_YmvaIso_event]

print_summary(branches, "YmvaIso")
# Out:
# Number of candidates YmvaIso: 1553
# Number of events YmvaIso: 1540

# %%
before_trig_cut_Y = ak.flatten(branches['Y_mass'])
Hpt_before_trig_cut_Y = ak.flatten(branches['Y_pt1'])
Lpt_before_trig_cut_Y = ak.flatten(branches['Y_pt2'])

before_trig_cut_Z = ak.flatten(branches['Z_mass'])
Hpt_before_trig_cut_Z = ak.flatten(branches['Z_pt1'])
Lpt_before_trig_cut_Z = ak.flatten(branches['Z_pt2'])

# %% [markdown]
# ## Plotting cut steps

# %%
plt.figure(figsize=(8, 8))
nbins, xlow, xhigh = 40, 7, 11

plt.hist(before_ID_cuts_Y, bins=nbins, label="Acceptance cut", alpha=0.5, range=(xlow, xhigh))
plt.hist(before_trig_cut_Y, bins=nbins, label=f"WP90 {eleID_cut_type}", alpha=0.5, range=(xlow, xhigh))
plt.xlabel('Dielectron inv mass (GeV)')
plt.ylabel(f"Counts / {(xhigh-xlow)/nbins:.2f} GeV")
plt.legend()
plt.tight_layout()
plt.savefig(f"{savepath}/Y_mass_dist_for {eleID_cut_type} cuts.png")

# %%
plt.figure(figsize=(8, 8))
nbins, xlow, xhigh = 40, 70, 110

plt.hist(before_mass_cuts_Z, bins=nbins, label="Acceptance cuts", alpha=0.5, range=(xlow, xhigh))
# plt.hist(before_ID_cuts_Z, bins=nbins, label="Mass cut", alpha=0.5, range=(xlow, xhigh))
plt.hist(before_trig_cut_Z, bins=nbins, label=f"WP90 {eleID_cut_type}", alpha=0.5, range=(xlow, xhigh))
plt.xlabel('Dimuon inv mass (GeV)')
plt.ylabel(f"Counts / {(xhigh-xlow)/nbins:.2f} GeV")
plt.legend()
plt.tight_layout()
plt.savefig(f"{savepath}/Z_mass_dist_for {eleID_cut_type} cuts.png")

# %%
plt.figure(figsize=(8, 8))
nbins, xlow, xhigh = 50, 5, 55

plt.hist(Hpt_before_mass_cuts_Y, bins=nbins, label="Acceptance cut", alpha=0.5, range=(xlow, xhigh))
# plt.hist(Hpt_before_ID_cuts_Y, bins=nbins, label="Mass", alpha=0.5, range=(xlow, xhigh))
plt.hist(Hpt_before_trig_cut_Y, bins=nbins, label=f"WP90 {eleID_cut_type}", alpha=0.5, range=(xlow, xhigh))
plt.xlabel('High pT electron (GeV)')
plt.ylabel(f"Counts / {(xhigh-xlow)/nbins:.2f} GeV")
plt.legend()
plt.tight_layout()
plt.savefig(f"{savepath}/Y_highPt_dist_for {eleID_cut_type} cuts.png")

plt.figure(figsize=(8, 8))
nbins, xlow, xhigh = 25, 5, 30

plt.hist(Lpt_before_mass_cuts_Y, bins=nbins, label="Acceptance cut", alpha=0.5, range=(xlow, xhigh))
# plt.hist(Lpt_before_ID_cuts_Y, bins=nbins, label="Mass", alpha=0.5, range=(xlow, xhigh))
plt.hist(Lpt_before_trig_cut_Y, bins=nbins, label=f"WP90 {eleID_cut_type}", alpha=0.5, range=(xlow, xhigh))
plt.xlabel('Low pT electron (GeV)')
plt.ylabel(f"Counts / {(xhigh-xlow)/nbins:.2f} GeV")
plt.legend()
plt.tight_layout()
plt.savefig(f"{savepath}/Y_lowPt_dist_for {eleID_cut_type} cuts.png")

# %%
plt.figure(figsize=(8, 8))
nbins, xlow, xhigh = 40, 20, 150

plt.hist(Hpt_before_mass_cuts_Z, bins=nbins, label="Acceptance cuts", alpha=0.5, range=(xlow, xhigh))
# plt.hist(Hpt_before_ID_cuts_Z, bins=nbins, label="Mass cut", alpha=0.5, range=(xlow, xhigh))
plt.hist(Hpt_before_trig_cut_Z, bins=nbins, label=f"WP90 {eleID_cut_type}", alpha=0.5, range=(xlow, xhigh))
plt.xlabel('High pT Muon (GeV)')
plt.ylabel(f"Counts / {(xhigh-xlow)/nbins:.2f} GeV")
plt.legend()
plt.tight_layout()
plt.savefig(f"{savepath}/Z_highPt_dist_for {eleID_cut_type} cuts.png")

plt.figure(figsize=(8, 8))
nbins, xlow, xhigh = 40, 0, 100

plt.hist(Lpt_before_mass_cuts_Z, bins=nbins, label="Acceptance cuts", alpha=0.5, range=(xlow, xhigh))
# plt.hist(Lpt_before_ID_cuts_Z, bins=nbins, label="Mass cut", alpha=0.5, range=(xlow, xhigh))
plt.hist(Lpt_before_trig_cut_Z, bins=nbins, label=f"WP90 {eleID_cut_type}", alpha=0.5, range=(xlow, xhigh))
plt.xlabel('Low pT Muon (GeV)')
plt.ylabel(f"Counts / {(xhigh-xlow)/nbins:.2f} GeV")
plt.legend()
plt.tight_layout()
plt.savefig(f"{savepath}/Z_lowPt_dist_for {eleID_cut_type} cuts.png")

# %%
# highestPt_muon = ak.argmax(branches.Z_highPt, axis=1, keepdims=True, mask_identity=True)

# cut_ZtrackIso_candi = (branches['Z_trackIso1'][highestPt_muon] < 0.35) & (branches['Z_trackIso2'][highestPt_muon] < 0.35)
# cut_ZtrackIso_event = ak.any(cut_ZtrackIso_candi, axis=1)

# plt.hist(ak.flatten(branches.Z_trackIso1[highestPt_muon]), bins=100, range=(0, 2), label="Z_trackIso1", alpha=0.5)
# plt.hist(ak.flatten(branches.Z_trackIso2[highestPt_muon]), bins=100, range=(0, 2), label="Z_trackIso2", alpha=0.5)
# plt.axvline(x=0.35, color='r')
# plt.xlabel('Z_trackIso')
# # plt.xlim([0,1])
# plt.legend()

# branches = branches[cut_ZtrackIso_candi][cut_ZtrackIso_event]

# print_summary(branches, "ZTrackIso")

# %% [markdown]
# ## Fitting

# %%
plt.figure(figsize=(8, 8))
nbins, xlow, xhigh = 40, 7, 11
plt.hist(ak.flatten(branches.Y_mass), bins=nbins, label="Y_mass", alpha=0.5, range=(xlow, xhigh))

# show mean and std on plot
mean = np.mean(ak.flatten(branches.Y_mass))
std = np.std(ak.flatten(branches.Y_mass))
plt.text(0.8, 0.9, f"Mean: {mean:.2f}\nStd: {std:.2f}", transform=plt.gca().transAxes, fontsize=12)
plt.text(0.8, 0.85, f"Events: {len(ak.flatten(branches.Y_mass))}", transform=plt.gca().transAxes, fontsize=12)

plt.xlabel('Dielectron inv mass (GeV)')
plt.ylabel(f"Counts / {(xhigh-xlow)/nbins:.2f} GeV")
plt.tight_layout()
plt.savefig(f"{savepath}/fit_histogram_Y_{eleID_cut_type}.png")

plt.figure(figsize=(8, 8))
nbins, xlow, xhigh = 40, 70, 110
plt.hist(ak.flatten(branches.Z_mass), bins=nbins, label="Z_mass", alpha=0.5, range=(xlow, xhigh))

# show mean and std on plot
mean = np.mean(ak.flatten(branches.Z_mass))
std = np.std(ak.flatten(branches.Z_mass))
plt.text(0.8, 0.9, f"Mean: {mean:.2f}\nStd: {std:.2f}", transform=plt.gca().transAxes, fontsize=12)
plt.text(0.8, 0.85, f"Events: {len(ak.flatten(branches.Z_mass))}", transform=plt.gca().transAxes, fontsize=12)

plt.xlabel('Dimuon inv mass (GeV)')
plt.ylabel(f"Counts / {(xhigh-xlow)/nbins:.2f} GeV")
plt.tight_layout()
plt.savefig(f"{savepath}/fit_histogram_Z_{eleID_cut_type}.png")

# %%
Z_candidates = ak.flatten(branches['Z_mass']).to_numpy()
Z_mass = ROOT.RooRealVar("Z_mass", "Z_mass", 70, 110, "GeV")
data = ROOT.RooDataSet.from_numpy({f"Z_mass": Z_candidates}, [Z_mass])

frame = fit_unbinned_gauss_with_background(data, Z_mass, 40)
# frame = fit_unbinned_double_gauss_Z(data, Z_mass, 40)

# Draw the frame on the canvas
canvas = ROOT.TCanvas("canvas", "Z Candidates")
frame.Draw()
canvas.Draw()
canvas.SaveAs(f"{savepath}/fit_gauss_Z_{eleID_cut_type}.png")
# Out:
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (background,gaussian)
#  **********
#  **    1 **SET PRINT           1
#  **********
#  **********
#  **    2 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 a0           1.00000e-01  2.00000e+00   -1.00000e+01  1.00000e+01
#      2 a1           1.00000e-01  2.00000e+00   -1.00000e+01  1.00000e+01
#      3 a2           1.00000e-01  2.00000e+00   -1.00000e+01  1.00000e+01
#      4 mean         9.10000e+01  2.00000e+00    8.00000e+01  1.00000e+02
#      5 nbkg         1.00000e+04  2.50000e+03    0.00000e+00  2.50000e+04
#      6 nsig         1.50000e+04  2.50000e+03    0.00000e+00  2.50000e+04
#      7 sigma        2.00000e+00  9.50000e-01    1.00000e-01  1.00000e+01
#  **********
#  **    3 **SET ERR         0.5
#  **********
#  **********
#  **    4 **SET PRINT           1
#  **********
#  **********
#  **    5 **SET STR           1
#  **********
#  NOW USING STRATEGY  1: TRY TO BALANCE SPEED AGAINST RELIABILITY
#  **********
#  **    6 **MIGRAD        3500           1
#  **********
#  FIRST CALL TO USER FUNCTION AT NEW START POINT, WITH IFLAG=4.
#  START MIGRAD MINIMIZATION.  STRATEGY  1.  CONVERGENCE WHEN EDM .LT. 1.00e-03
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (13739.3) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	a0=0.1	a1=0.1	a2=-0.0152495	mean=91	nbkg=10000	nsig=15000	sigma=2
# RooPolynomial::background[ x=Z_mass coefList=(a0,a1,a2) ]
#      p.d.f normalization integral is zero or negative: -433301.226382 @ x=Z_mass=77.2702, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.0152495)
#      p.d.f normalization integral is zero or negative: -433301.226382 @ x=Z_mass=90.3622, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.0152495)
#      p.d.f normalization integral is zero or negative: -433301.226382 @ x=Z_mass=89.8016, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.0152495)
#      p.d.f normalization integral is zero or negative: -433301.226382 @ x=Z_mass=89.907, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.0152495)
#      p.d.f normalization integral is zero or negative: -433301.226382 @ x=Z_mass=90.8308, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.0152495)
#      p.d.f normalization integral is zero or negative: -433301.226382 @ x=Z_mass=87.6007, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.0152495)
#      p.d.f normalization integral is zero or negative: -433301.226382 @ x=Z_mass=91.8004, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.0152495)
#      p.d.f normalization integral is zero or negative: -433301.226382 @ x=Z_mass=90.3267, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.0152495)
#      p.d.f normalization integral is zero or negative: -433301.226382 @ x=Z_mass=88.3139, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.0152495)
#      p.d.f normalization integral is zero or negative: -433301.226382 @ x=Z_mass=92.5626, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.0152495)
#      p.d.f normalization integral is zero or negative: -433301.226382 @ x=Z_mass=88.2884, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.0152495)
#      p.d.f normalization integral is zero or negative: -433301.226382 @ x=Z_mass=89.9794, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.0152495)
#     ... (remaining 1543 messages suppressed)
# RooAddPdf::model[ nbkg * background + nsig * gaussian ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -6429.66/-433301,gaussian = 5.8423e-11/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -10425.1/-433301,gaussian = 0.950421/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -10227.1/-433301,gaussian = 0.835674/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -10264.1/-433301,gaussian = 0.861287/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -10592.5/-433301,gaussian = 0.996428/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -9474.13/-433301,gaussian = 0.235882/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -10944.6/-433301,gaussian = 0.923048/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -10412.5/-433301,gaussian = 0.944911/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -9713.96/-433301,gaussian = 0.405813/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -11226.7/-433301,gaussian = 0.736972/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -9705.31/-433301,gaussian = 0.398891/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -10289.6/-433301,gaussian = 0.877922/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#     ... (remaining 1543 messages suppressed)
# RooNLLVar::nll_model_[ paramSet=(a0,a1,a2,mean,nbkg,nsig,sigma) ]
#      function value is NAN @ paramSet=(a0 = 0.1,a1 = 0.1,a2 = -0.0152495,mean = 91,nbkg = 10000,nsig = 15000,sigma = 2)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (13877) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	a0=0.1	a1=0.1	a2=-0.0728744	mean=91	nbkg=10000	nsig=15000	sigma=2
# RooPolynomial::background[ x=Z_mass coefList=(a0,a1,a2) ]
#      p.d.f normalization integral is zero or negative: -2196624.540533 @ x=Z_mass=77.2702, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.0728744)
#      p.d.f normalization integral is zero or negative: -2196624.540533 @ x=Z_mass=90.3622, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.0728744)
#      p.d.f normalization integral is zero or negative: -2196624.540533 @ x=Z_mass=89.8016, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.0728744)
#      p.d.f normalization integral is zero or negative: -2196624.540533 @ x=Z_mass=89.907, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.0728744)
#      p.d.f normalization integral is zero or negative: -2196624.540533 @ x=Z_mass=90.8308, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.0728744)
#      p.d.f normalization integral is zero or negative: -2196624.540533 @ x=Z_mass=87.6007, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.0728744)
#      p.d.f normalization integral is zero or negative: -2196624.540533 @ x=Z_mass=91.8004, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.0728744)
#      p.d.f normalization integral is zero or negative: -2196624.540533 @ x=Z_mass=90.3267, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.0728744)
#      p.d.f normalization integral is zero or negative: -2196624.540533 @ x=Z_mass=88.3139, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.0728744)
#      p.d.f normalization integral is zero or negative: -2196624.540533 @ x=Z_mass=92.5626, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.0728744)
#      p.d.f normalization integral is zero or negative: -2196624.540533 @ x=Z_mass=88.2884, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.0728744)
#      p.d.f normalization integral is zero or negative: -2196624.540533 @ x=Z_mass=89.9794, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.0728744)
#     ... (remaining 1543 messages suppressed)
# RooAddPdf::model[ nbkg * background + nsig * gaussian ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -33015.3/-2.19662e+06,gaussian = 5.8423e-11/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -52942.9/-2.19662e+06,gaussian = 0.950421/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -51958.5/-2.19662e+06,gaussian = 0.835674/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -52142.7/-2.19662e+06,gaussian = 0.861287/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -53775.2/-2.19662e+06,gaussian = 0.996428/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -48211.7/-2.19662e+06,gaussian = 0.235882/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -55524.9/-2.19662e+06,gaussian = 0.923048/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -52880.2/-2.19662e+06,gaussian = 0.944911/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -49405.5/-2.19662e+06,gaussian = 0.405813/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -56926.8/-2.19662e+06,gaussian = 0.736972/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -49362.5/-2.19662e+06,gaussian = 0.398891/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -52269.4/-2.19662e+06,gaussian = 0.877922/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#     ... (remaining 1543 messages suppressed)
# RooNLLVar::nll_model_[ paramSet=(a0,a1,a2,mean,nbkg,nsig,sigma) ]
#      function value is NAN @ paramSet=(a0 = 0.1,a1 = 0.1,a2 = -0.0728744,mean = 91,nbkg = 10000,nsig = 15000,sigma = 2)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (13877) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	a0=0.1	a1=0.1	a2=-0.0152495	mean=91	nbkg=10000	nsig=15000	sigma=2
# RooPolynomial::background[ x=Z_mass coefList=(a0,a1,a2) ]
#      p.d.f normalization integral is zero or negative: -433301.226382 @ x=Z_mass=77.2702, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.0152495)
#      p.d.f normalization integral is zero or negative: -433301.226382 @ x=Z_mass=90.3622, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.0152495)
#      p.d.f normalization integral is zero or negative: -433301.226382 @ x=Z_mass=89.8016, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.0152495)
#      p.d.f normalization integral is zero or negative: -433301.226382 @ x=Z_mass=89.907, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.0152495)
#      p.d.f normalization integral is zero or negative: -433301.226382 @ x=Z_mass=90.8308, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.0152495)
#      p.d.f normalization integral is zero or negative: -433301.226382 @ x=Z_mass=87.6007, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.0152495)
#      p.d.f normalization integral is zero or negative: -433301.226382 @ x=Z_mass=91.8004, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.0152495)
#      p.d.f normalization integral is zero or negative: -433301.226382 @ x=Z_mass=90.3267, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.0152495)
#      p.d.f normalization integral is zero or negative: -433301.226382 @ x=Z_mass=88.3139, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.0152495)
#      p.d.f normalization integral is zero or negative: -433301.226382 @ x=Z_mass=92.5626, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.0152495)
#      p.d.f normalization integral is zero or negative: -433301.226382 @ x=Z_mass=88.2884, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.0152495)
#      p.d.f normalization integral is zero or negative: -433301.226382 @ x=Z_mass=89.9794, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.0152495)
#     ... (remaining 1543 messages suppressed)
# RooAddPdf::model[ nbkg * background + nsig * gaussian ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -6429.66/-433301,gaussian = 5.8423e-11/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -10425.1/-433301,gaussian = 0.950421/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -10227.1/-433301,gaussian = 0.835674/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -10264.1/-433301,gaussian = 0.861287/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -10592.5/-433301,gaussian = 0.996428/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -9474.13/-433301,gaussian = 0.235882/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -10944.6/-433301,gaussian = 0.923048/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -10412.5/-433301,gaussian = 0.944911/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -9713.96/-433301,gaussian = 0.405813/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -11226.7/-433301,gaussian = 0.736972/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -9705.31/-433301,gaussian = 0.398891/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -10289.6/-433301,gaussian = 0.877922/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#     ... (remaining 1543 messages suppressed)
# RooNLLVar::nll_model_[ paramSet=(a0,a1,a2,mean,nbkg,nsig,sigma) ]
#      function value is NAN @ paramSet=(a0 = 0.1,a1 = 0.1,a2 = -0.0152495,mean = 91,nbkg = 10000,nsig = 15000,sigma = 2)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (13877) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	a0=0.1	a1=0.1	a2=-0.0146732	mean=91	nbkg=10000	nsig=15000	sigma=2
# RooPolynomial::background[ x=Z_mass coefList=(a0,a1,a2) ]
#      p.d.f normalization integral is zero or negative: -415667.817406 @ x=Z_mass=77.2702, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.0146732)
#      p.d.f normalization integral is zero or negative: -415667.817406 @ x=Z_mass=90.3622, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.0146732)
#      p.d.f normalization integral is zero or negative: -415667.817406 @ x=Z_mass=89.8016, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.0146732)
#      p.d.f normalization integral is zero or negative: -415667.817406 @ x=Z_mass=89.907, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.0146732)
#      p.d.f normalization integral is zero or negative: -415667.817406 @ x=Z_mass=90.8308, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.0146732)
#      p.d.f normalization integral is zero or negative: -415667.817406 @ x=Z_mass=87.6007, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.0146732)
#      p.d.f normalization integral is zero or negative: -415667.817406 @ x=Z_mass=91.8004, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.0146732)
#      p.d.f normalization integral is zero or negative: -415667.817406 @ x=Z_mass=90.3267, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.0146732)
#      p.d.f normalization integral is zero or negative: -415667.817406 @ x=Z_mass=88.3139, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.0146732)
#      p.d.f normalization integral is zero or negative: -415667.817406 @ x=Z_mass=92.5626, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.0146732)
#      p.d.f normalization integral is zero or negative: -415667.817406 @ x=Z_mass=88.2884, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.0146732)
#      p.d.f normalization integral is zero or negative: -415667.817406 @ x=Z_mass=89.9794, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.0146732)
#     ... (remaining 1543 messages suppressed)
# RooAddPdf::model[ nbkg * background + nsig * gaussian ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -6163.8/-415668,gaussian = 5.8423e-11/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -9999.89/-415668,gaussian = 0.950421/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -9809.8/-415668,gaussian = 0.835674/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -9845.35/-415668,gaussian = 0.861287/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -10160.7/-415668,gaussian = 0.996428/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -9086.75/-415668,gaussian = 0.235882/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -10498.7/-415668,gaussian = 0.923048/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -9987.78/-415668,gaussian = 0.944911/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -9317.04/-415668,gaussian = 0.405813/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -10769.7/-415668,gaussian = 0.736972/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -9308.74/-415668,gaussian = 0.398891/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -9869.83/-415668,gaussian = 0.877922/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#     ... (remaining 1543 messages suppressed)
# RooNLLVar::nll_model_[ paramSet=(a0,a1,a2,mean,nbkg,nsig,sigma) ]
#      function value is NAN @ paramSet=(a0 = 0.1,a1 = 0.1,a2 = -0.0146732,mean = 91,nbkg = 10000,nsig = 15000,sigma = 2)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (13877) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	a0=0.1	a1=0.1	a2=-0.014097	mean=91	nbkg=10000	nsig=15000	sigma=2
# RooPolynomial::background[ x=Z_mass coefList=(a0,a1,a2) ]
#      p.d.f normalization integral is zero or negative: -398034.406938 @ x=Z_mass=77.2702, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.014097)
#      p.d.f normalization integral is zero or negative: -398034.406938 @ x=Z_mass=90.3622, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.014097)
#      p.d.f normalization integral is zero or negative: -398034.406938 @ x=Z_mass=89.8016, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.014097)
#      p.d.f normalization integral is zero or negative: -398034.406938 @ x=Z_mass=89.907, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.014097)
#      p.d.f normalization integral is zero or negative: -398034.406938 @ x=Z_mass=90.8308, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.014097)
#      p.d.f normalization integral is zero or negative: -398034.406938 @ x=Z_mass=87.6007, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.014097)
#      p.d.f normalization integral is zero or negative: -398034.406938 @ x=Z_mass=91.8004, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.014097)
#      p.d.f normalization integral is zero or negative: -398034.406938 @ x=Z_mass=90.3267, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.014097)
#      p.d.f normalization integral is zero or negative: -398034.406938 @ x=Z_mass=88.3139, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.014097)
#      p.d.f normalization integral is zero or negative: -398034.406938 @ x=Z_mass=92.5626, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.014097)
#      p.d.f normalization integral is zero or negative: -398034.406938 @ x=Z_mass=88.2884, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.014097)
#      p.d.f normalization integral is zero or negative: -398034.406938 @ x=Z_mass=89.9794, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.014097)
#     ... (remaining 1543 messages suppressed)
# RooAddPdf::model[ nbkg * background + nsig * gaussian ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -5897.94/-398034,gaussian = 5.8423e-11/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -9574.7/-398034,gaussian = 0.950421/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -9392.48/-398034,gaussian = 0.835674/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -9426.56/-398034,gaussian = 0.861287/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -9728.83/-398034,gaussian = 0.996428/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -8699.37/-398034,gaussian = 0.235882/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -10052.9/-398034,gaussian = 0.923048/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -9563.1/-398034,gaussian = 0.944911/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -8920.12/-398034,gaussian = 0.405813/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -10312.7/-398034,gaussian = 0.736972/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -8912.16/-398034,gaussian = 0.398891/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -9450.03/-398034,gaussian = 0.877922/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#     ... (remaining 1543 messages suppressed)
# RooNLLVar::nll_model_[ paramSet=(a0,a1,a2,mean,nbkg,nsig,sigma) ]
#      function value is NAN @ paramSet=(a0 = 0.1,a1 = 0.1,a2 = -0.014097,mean = 91,nbkg = 10000,nsig = 15000,sigma = 2)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (13877) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	a0=0.1	a1=0.1	a2=-0.00732598	mean=91	nbkg=10000	nsig=15000	sigma=2
# RooPolynomial::background[ x=Z_mass coefList=(a0,a1,a2) ]
#      p.d.f normalization integral is zero or negative: -190841.742365 @ x=Z_mass=77.2702, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.00732598)
#      p.d.f normalization integral is zero or negative: -190841.742365 @ x=Z_mass=90.3622, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.00732598)
#      p.d.f normalization integral is zero or negative: -190841.742365 @ x=Z_mass=89.8016, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.00732598)
#      p.d.f normalization integral is zero or negative: -190841.742365 @ x=Z_mass=89.907, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.00732598)
#      p.d.f normalization integral is zero or negative: -190841.742365 @ x=Z_mass=90.8308, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.00732598)
#      p.d.f normalization integral is zero or negative: -190841.742365 @ x=Z_mass=87.6007, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.00732598)
#      p.d.f normalization integral is zero or negative: -190841.742365 @ x=Z_mass=91.8004, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.00732598)
#      p.d.f normalization integral is zero or negative: -190841.742365 @ x=Z_mass=90.3267, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.00732598)
#      p.d.f normalization integral is zero or negative: -190841.742365 @ x=Z_mass=88.3139, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.00732598)
#      p.d.f normalization integral is zero or negative: -190841.742365 @ x=Z_mass=92.5626, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.00732598)
#      p.d.f normalization integral is zero or negative: -190841.742365 @ x=Z_mass=88.2884, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.00732598)
#      p.d.f normalization integral is zero or negative: -190841.742365 @ x=Z_mass=89.9794, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.00732598)
#     ... (remaining 1543 messages suppressed)
# RooAddPdf::model[ nbkg * background + nsig * gaussian ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -2774.09/-190842,gaussian = 5.8423e-11/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -4578.81/-190842,gaussian = 0.950421/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -4488.99/-190842,gaussian = 0.835674/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -4505.79/-190842,gaussian = 0.861287/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -4654.81/-190842,gaussian = 0.996428/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -4147.65/-190842,gaussian = 0.235882/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -4814.69/-190842,gaussian = 0.923048/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -4573.09/-190842,gaussian = 0.944911/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -4256.31/-190842,gaussian = 0.405813/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -4942.91/-190842,gaussian = 0.736972/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -4252.39/-190842,gaussian = 0.398891/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -4517.35/-190842,gaussian = 0.877922/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#     ... (remaining 1543 messages suppressed)
# RooNLLVar::nll_model_[ paramSet=(a0,a1,a2,mean,nbkg,nsig,sigma) ]
#      function value is NAN @ paramSet=(a0 = 0.1,a1 = 0.1,a2 = -0.00732598,mean = 91,nbkg = 10000,nsig = 15000,sigma = 2)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (13877) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	a0=-4.70626	a1=0.1	a2=-0.000554977	mean=91	nbkg=10000	nsig=15000	sigma=2
# RooPolynomial::background[ x=Z_mass coefList=(a0,a1,a2) ]
#      p.d.f normalization integral is zero or negative: -951.501695 @ x=Z_mass=77.2702, coefList=(a0 = -4.70626,a1 = 0.1,a2 = -0.000554977)
#      p.d.f normalization integral is zero or negative: -951.501695 @ x=Z_mass=90.3622, coefList=(a0 = -4.70626,a1 = 0.1,a2 = -0.000554977)
#      p.d.f normalization integral is zero or negative: -951.501695 @ x=Z_mass=89.8016, coefList=(a0 = -4.70626,a1 = 0.1,a2 = -0.000554977)
#      p.d.f normalization integral is zero or negative: -951.501695 @ x=Z_mass=89.907, coefList=(a0 = -4.70626,a1 = 0.1,a2 = -0.000554977)
#      p.d.f normalization integral is zero or negative: -951.501695 @ x=Z_mass=90.8308, coefList=(a0 = -4.70626,a1 = 0.1,a2 = -0.000554977)
#      p.d.f normalization integral is zero or negative: -951.501695 @ x=Z_mass=87.6007, coefList=(a0 = -4.70626,a1 = 0.1,a2 = -0.000554977)
#      p.d.f normalization integral is zero or negative: -951.501695 @ x=Z_mass=91.8004, coefList=(a0 = -4.70626,a1 = 0.1,a2 = -0.000554977)
#      p.d.f normalization integral is zero or negative: -951.501695 @ x=Z_mass=90.3267, coefList=(a0 = -4.70626,a1 = 0.1,a2 = -0.000554977)
#      p.d.f normalization integral is zero or negative: -951.501695 @ x=Z_mass=88.3139, coefList=(a0 = -4.70626,a1 = 0.1,a2 = -0.000554977)
#      p.d.f normalization integral is zero or negative: -951.501695 @ x=Z_mass=92.5626, coefList=(a0 = -4.70626,a1 = 0.1,a2 = -0.000554977)
#      p.d.f normalization integral is zero or negative: -951.501695 @ x=Z_mass=88.2884, coefList=(a0 = -4.70626,a1 = 0.1,a2 = -0.000554977)
#      p.d.f normalization integral is zero or negative: -951.501695 @ x=Z_mass=89.9794, coefList=(a0 = -4.70626,a1 = 0.1,a2 = -0.000554977)
#     ... (remaining 1543 messages suppressed)
# RooAddPdf::model[ nbkg * background + nsig * gaussian ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -21.6272/-951.502,gaussian = 5.8423e-11/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -17.2179/-951.502,gaussian = 0.950421/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -17.1055/-951.502,gaussian = 0.835674/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -17.1242/-951.502,gaussian = 0.861287/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -17.3361/-951.502,gaussian = 0.996428/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -16.9598/-951.502,gaussian = 0.235882/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -17.6525/-951.502,gaussian = 0.923048/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -17.2098/-951.502,gaussian = 0.944911/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -16.9567/-951.502,gaussian = 0.405813/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -17.9709/-951.502,gaussian = 0.736972/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -16.9559/-951.502,gaussian = 0.398891/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -17.1378/-951.502,gaussian = 0.877922/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#     ... (remaining 1543 messages suppressed)
# RooNLLVar::nll_model_[ paramSet=(a0,a1,a2,mean,nbkg,nsig,sigma) ]
#      function value is NAN @ paramSet=(a0 = -4.70626,a1 = 0.1,a2 = -0.000554977,mean = 91,nbkg = 10000,nsig = 15000,sigma = 2)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (13877) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	a0=0.1	a1=0.00590508	a2=-0.000554977	mean=91	nbkg=10000	nsig=15000	sigma=2
# RooPolynomial::background[ x=Z_mass coefList=(a0,a1,a2) ]
#      p.d.f normalization integral is zero or negative: -14637.569381 @ x=Z_mass=77.2702, coefList=(a0 = 0.1,a1 = 0.00590508,a2 = -0.000554977)
#      p.d.f normalization integral is zero or negative: -14637.569381 @ x=Z_mass=90.3622, coefList=(a0 = 0.1,a1 = 0.00590508,a2 = -0.000554977)
#      p.d.f normalization integral is zero or negative: -14637.569381 @ x=Z_mass=89.8016, coefList=(a0 = 0.1,a1 = 0.00590508,a2 = -0.000554977)
#      p.d.f normalization integral is zero or negative: -14637.569381 @ x=Z_mass=89.907, coefList=(a0 = 0.1,a1 = 0.00590508,a2 = -0.000554977)
#      p.d.f normalization integral is zero or negative: -14637.569381 @ x=Z_mass=90.8308, coefList=(a0 = 0.1,a1 = 0.00590508,a2 = -0.000554977)
#      p.d.f normalization integral is zero or negative: -14637.569381 @ x=Z_mass=87.6007, coefList=(a0 = 0.1,a1 = 0.00590508,a2 = -0.000554977)
#      p.d.f normalization integral is zero or negative: -14637.569381 @ x=Z_mass=91.8004, coefList=(a0 = 0.1,a1 = 0.00590508,a2 = -0.000554977)
#      p.d.f normalization integral is zero or negative: -14637.569381 @ x=Z_mass=90.3267, coefList=(a0 = 0.1,a1 = 0.00590508,a2 = -0.000554977)
#      p.d.f normalization integral is zero or negative: -14637.569381 @ x=Z_mass=88.3139, coefList=(a0 = 0.1,a1 = 0.00590508,a2 = -0.000554977)
#      p.d.f normalization integral is zero or negative: -14637.569381 @ x=Z_mass=92.5626, coefList=(a0 = 0.1,a1 = 0.00590508,a2 = -0.000554977)
#      p.d.f normalization integral is zero or negative: -14637.569381 @ x=Z_mass=88.2884, coefList=(a0 = 0.1,a1 = 0.00590508,a2 = -0.000554977)
#      p.d.f normalization integral is zero or negative: -14637.569381 @ x=Z_mass=89.9794, coefList=(a0 = 0.1,a1 = 0.00590508,a2 = -0.000554977)
#     ... (remaining 1543 messages suppressed)
# RooAddPdf::model[ nbkg * background + nsig * gaussian ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -212.058/-14637.6,gaussian = 5.8423e-11/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -351.23/-14637.6,gaussian = 0.950421/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -344.308/-14637.6,gaussian = 0.835674/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -345.603/-14637.6,gaussian = 0.861287/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -357.085/-14637.6,gaussian = 0.996428/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -318.001/-14637.6,gaussian = 0.235882/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -369.403/-14637.6,gaussian = 0.923048/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -350.789/-14637.6,gaussian = 0.944911/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -326.377/-14637.6,gaussian = 0.405813/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -379.281/-14637.6,gaussian = 0.736972/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -326.075/-14637.6,gaussian = 0.398891/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -346.494/-14637.6,gaussian = 0.877922/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#     ... (remaining 1543 messages suppressed)
# RooNLLVar::nll_model_[ paramSet=(a0,a1,a2,mean,nbkg,nsig,sigma) ]
#      function value is NAN @ paramSet=(a0 = 0.1,a1 = 0.00590508,a2 = -0.000554977,mean = 91,nbkg = 10000,nsig = 15000,sigma = 2)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (13877) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	a0=0.1	a1=0.1	a2=-0.0106115	mean=91	nbkg=10000	nsig=15000	sigma=2
# RooPolynomial::background[ x=Z_mass coefList=(a0,a1,a2) ]
#      p.d.f normalization integral is zero or negative: -291379.477301 @ x=Z_mass=77.2702, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.0106115)
#      p.d.f normalization integral is zero or negative: -291379.477301 @ x=Z_mass=90.3622, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.0106115)
#      p.d.f normalization integral is zero or negative: -291379.477301 @ x=Z_mass=89.8016, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.0106115)
#      p.d.f normalization integral is zero or negative: -291379.477301 @ x=Z_mass=89.907, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.0106115)
#      p.d.f normalization integral is zero or negative: -291379.477301 @ x=Z_mass=90.8308, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.0106115)
#      p.d.f normalization integral is zero or negative: -291379.477301 @ x=Z_mass=87.6007, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.0106115)
#      p.d.f normalization integral is zero or negative: -291379.477301 @ x=Z_mass=91.8004, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.0106115)
#      p.d.f normalization integral is zero or negative: -291379.477301 @ x=Z_mass=90.3267, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.0106115)
#      p.d.f normalization integral is zero or negative: -291379.477301 @ x=Z_mass=88.3139, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.0106115)
#      p.d.f normalization integral is zero or negative: -291379.477301 @ x=Z_mass=92.5626, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.0106115)
#      p.d.f normalization integral is zero or negative: -291379.477301 @ x=Z_mass=88.2884, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.0106115)
#      p.d.f normalization integral is zero or negative: -291379.477301 @ x=Z_mass=89.9794, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.0106115)
#     ... (remaining 1543 messages suppressed)
# RooAddPdf::model[ nbkg * background + nsig * gaussian ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -4289.9/-291379,gaussian = 5.8423e-11/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -7003.01/-291379,gaussian = 0.950421/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -6868.35/-291379,gaussian = 0.835674/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -6893.53/-291379,gaussian = 0.861287/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -7116.92/-291379,gaussian = 0.996428/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -6356.31/-291379,gaussian = 0.235882/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -7356.49/-291379,gaussian = 0.923048/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -6994.43/-291379,gaussian = 0.944911/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -6519.37/-291379,gaussian = 0.405813/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -7548.55/-291379,gaussian = 0.736972/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -6513.49/-291379,gaussian = 0.398891/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -6910.87/-291379,gaussian = 0.877922/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#     ... (remaining 1543 messages suppressed)
# RooNLLVar::nll_model_[ paramSet=(a0,a1,a2,mean,nbkg,nsig,sigma) ]
#      function value is NAN @ paramSet=(a0 = 0.1,a1 = 0.1,a2 = -0.0106115,mean = 91,nbkg = 10000,nsig = 15000,sigma = 2)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (13877) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	a0=0.1	a1=0.1	a2=-0.00156063	mean=91	nbkg=10000	nsig=15000	sigma=2
# RooPolynomial::background[ x=Z_mass coefList=(a0,a1,a2) ]
#      p.d.f normalization integral is zero or negative: -14422.031152 @ x=Z_mass=77.2702, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.00156063)
#      p.d.f normalization integral is zero or negative: -14422.031152 @ x=Z_mass=90.3622, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.00156063)
#      p.d.f normalization integral is zero or negative: -14422.031152 @ x=Z_mass=89.8016, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.00156063)
#      p.d.f normalization integral is zero or negative: -14422.031152 @ x=Z_mass=89.907, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.00156063)
#      p.d.f normalization integral is zero or negative: -14422.031152 @ x=Z_mass=90.8308, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.00156063)
#      p.d.f normalization integral is zero or negative: -14422.031152 @ x=Z_mass=87.6007, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.00156063)
#      p.d.f normalization integral is zero or negative: -14422.031152 @ x=Z_mass=91.8004, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.00156063)
#      p.d.f normalization integral is zero or negative: -14422.031152 @ x=Z_mass=90.3267, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.00156063)
#      p.d.f normalization integral is zero or negative: -14422.031152 @ x=Z_mass=88.3139, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.00156063)
#      p.d.f normalization integral is zero or negative: -14422.031152 @ x=Z_mass=92.5626, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.00156063)
#      p.d.f normalization integral is zero or negative: -14422.031152 @ x=Z_mass=88.2884, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.00156063)
#      p.d.f normalization integral is zero or negative: -14422.031152 @ x=Z_mass=89.9794, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.00156063)
#     ... (remaining 1543 messages suppressed)
# RooAddPdf::model[ nbkg * background + nsig * gaussian ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -114.212/-14422,gaussian = 5.8423e-11/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -324.923/-14422,gaussian = 0.950421/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -313.781/-14422,gaussian = 0.835674/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -315.861/-14422,gaussian = 0.861287/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -334.394/-14422,gaussian = 0.996428/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -271.967/-14422,gaussian = 0.235882/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -354.442/-14422,gaussian = 0.923048/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -324.212/-14422,gaussian = 0.944911/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -285.184/-14422,gaussian = 0.405813/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -370.637/-14422,gaussian = 0.736972/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -284.706/-14422,gaussian = 0.398891/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -317.294/-14422,gaussian = 0.877922/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
#     ... (remaining 1543 messages suppressed)
# RooNLLVar::nll_model_[ paramSet=(a0,a1,a2,mean,nbkg,nsig,sigma) ]
#      function value is NAN @ paramSet=(a0 = 0.1,a1 = 0.1,a2 = -0.00156063,mean = 91,nbkg = 10000,nsig = 15000,sigma = 2)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (13877) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	a0=-5.66047	a1=0.1	a2=-0.000554977	mean=91	nbkg=10000	nsig=15000	sigma=2
# RooPolynomial::background[ x=Z_mass coefList=(a0,a1,a2) ]
#      p.d.f normalization integral is zero or negative: -4386.684108 @ x=Z_mass=77.2702, coefList=(a0 = -5.66047,a1 = 0.1,a2 = -0.000554977)
#      p.d.f normalization integral is zero or negative: -4386.684108 @ x=Z_mass=90.3622, coefList=(a0 = -5.66047,a1 = 0.1,a2 = -0.000554977)
#      p.d.f normalization integral is zero or negative: -4386.684108 @ x=Z_mass=89.8016, coefList=(a0 = -5.66047,a1 = 0.1,a2 = -0.000554977)
#      p.d.f normalization integral is zero or negative: -4386.684108 @ x=Z_mass=89.907, coefList=(a0 = -5.66047,a1 = 0.1,a2 = -0.000554977)
#      p.d.f normalization integral is zero or negative: -4386.684108 @ x=Z_mass=90.8308, coefList=(a0 = -5.66047,a1 = 0.1,a2 = -0.000554977)
#      p.d.f normalization integral is zero or negative: -4386.684108 @ x=Z_mass=87.6007, coefList=(a0 = -5.66047,a1 = 0.1,a2 = -0.000554977)
#      p.d.f normalization integral is zero or negative: -4386.684108 @ x=Z_mass=91.8004, coefList=(a0 = -5.66047,a1 = 0.1,a2 = -0.000554977)
#      p.d.f normalization integral is zero or negative: -4386.684108 @ x=Z_mass=90.3267, coefList=(a0 = -5.66047,a1 = 0.1,a2 = -0.000554977)
#      p.d.f normalization integral is zero or negative: -4386.684108 @ x=Z_mass=88.3139, coefList=(a0 = -5.66047,a1 = 0.1,a2 = -0.000554977)
#      p.d.f normalization integral is zero or negative: -4386.684108 @ x=Z_mass=92.5626, coefList=(a0 = -5.66047,a1 = 0.1,a2 = -0.000554977)
#      p.d.f normalization integral is zero or negative: -4386.684108 @ x=Z_mass=88.2884, coefList=(a0 = -5.66047,a1 = 0.1,a2 = -0.000554977)
#      p.d.f normalization integral is zero or negative: -4386.684108 @ x=Z_mass=89.9794, coefList=(a0 = -5.66047,a1 = 0.1,a2 = -0.000554977)
#     ... (remaining 1543 messages suppressed)
# RooAddPdf::model[ nbkg * background + nsig * gaussian ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -95.3598/-4386.68,gaussian = 5.8423e-11/5.01326), !coefficients=(nbkg = 10000,nsig = 15000)
# ...
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -104.743/-4795.03,gaussian = 0.885032/5.46411), !coefficients=(nbkg = 334.898,nsig = 1217.78)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -105.224/-4795.03,gaussian = 0.905377/5.46411), !coefficients=(nbkg = 334.898,nsig = 1217.78)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -109.545/-4795.03,gaussian = 0.999756/5.46411), !coefficients=(nbkg = 334.898,nsig = 1217.78)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -95.2217/-4795.03,gaussian = 0.322758/5.46411), !coefficients=(nbkg = 334.898,nsig = 1217.78)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -114.28/-4795.03,gaussian = 0.914542/5.46411), !coefficients=(nbkg = 334.898,nsig = 1217.78)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -107.165/-4795.03,gaussian = 0.968418/5.46411), !coefficients=(nbkg = 334.898,nsig = 1217.78)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -98.1975/-4795.03,gaussian = 0.500424/5.46411), !coefficients=(nbkg = 334.898,nsig = 1217.78)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -118.148/-4795.03,gaussian = 0.742109/5.46411), !coefficients=(nbkg = 334.898,nsig = 1217.78)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -98.0893/-4795.03,gaussian = 0.49355/5.46411), !coefficients=(nbkg = 334.898,nsig = 1217.78)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -105.556/-4795.03,gaussian = 0.91838/5.46411), !coefficients=(nbkg = 334.898,nsig = 1217.78)
#     ... (remaining 1543 messages suppressed)
# RooNLLVar::nll_model_[ paramSet=(a0,a1,a2,mean,nbkg,nsig,sigma) ]
#      function value is NAN @ paramSet=(a0 = -3.9602,a1 = 0.0995964,a2 = -0.00076401,mean = 90.879,nbkg = 334.898,nsig = 1217.78,sigma = 2.17986)
#
#  MIGRAD FAILS TO FIND IMPROVEMENT
#  MIGRAD TERMINATED WITHOUT CONVERGENCE.
#  FCN=-5578.63 FROM MIGRAD    STATUS=FAILED        848 CALLS         849 TOTAL
#                      EDM=1.88902e+11    STRATEGY= 1      ERR MATRIX NOT POS-DEF
#   EXT PARAMETER                APPROXIMATE        STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  a0          -3.96020e+00   1.64079e-07  -0.00000e+00   1.27907e+03
#    2  a1           9.95964e-02   3.95727e-06  -0.00000e+00   1.68493e+05
#    3  a2          -5.75629e-04   3.13786e-01  -0.00000e+00   1.95852e+07
#    4  mean         9.08790e+01   1.72598e-07   0.00000e+00  -1.45632e+00
#    5  nbkg         3.34898e+02   4.98263e-05   0.00000e+00   5.69213e-01
#    6  nsig         1.21778e+03   9.32502e-05   0.00000e+00   1.71834e+00
#    7  sigma        2.17986e+00   6.98749e-08   0.00000e+00   6.47422e-01
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  7    ERR DEF=0.5
#   2.692e-14  1.589e-13  1.261e-08 -1.157e-16 -7.463e-14 -7.201e-14 -3.662e-17
#   1.589e-13  1.566e-11  1.241e-06 -1.138e-14 -7.342e-12 -7.084e-12 -3.602e-15
#   1.261e-08  1.241e-06  9.849e-02 -9.036e-10 -5.828e-07 -5.624e-07 -2.859e-10
#  -1.157e-16 -1.138e-14 -9.036e-10  2.979e-14  5.347e-15  5.159e-15  2.623e-18
#  -7.463e-14 -7.342e-12 -5.828e-07  5.347e-15  2.483e-09  3.328e-12  1.692e-15
#  -7.201e-14 -7.084e-12 -5.624e-07  5.159e-15  3.328e-12  8.696e-09  1.633e-15
#  -3.662e-17 -3.602e-15 -2.859e-10  2.623e-18  1.692e-15  1.633e-15  4.882e-15
# ERR MATRIX NOT POS-DEF
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2      3      4      5      6      7
#         1  0.24493   1.000  0.245  0.245 -0.004 -0.009 -0.005 -0.003
#         2  0.99900   0.245  1.000  0.999 -0.017 -0.037 -0.019 -0.013
#         3  0.99900   0.245  0.999  1.000 -0.017 -0.037 -0.019 -0.013
#         4  0.01668  -0.004 -0.017 -0.017  1.000  0.001  0.000  0.000
#         5  0.03727  -0.009 -0.037 -0.037  0.001  1.000  0.001  0.000
#         6  0.01922  -0.005 -0.019 -0.019  0.000  0.001  1.000  0.000
#         7  0.01304  -0.003 -0.013 -0.013  0.000  0.000  0.000  1.000
#  ERR MATRIX NOT POS-DEF
#  **********
#  **    7 **SET ERR         0.5
#  **********
#  **********
#  **    8 **SET PRINT           1
#  **********
#  **********
#  **    9 **HESSE        3500
#  **********
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (13877) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	a0=-3.9602	a1=0.0995964	a2=-0.000596985	mean=90.879	nbkg=334.898	nsig=1217.78	sigma=2.17986
# RooPolynomial::background[ x=Z_mass coefList=(a0,a1,a2) ]
#      p.d.f value is less than zero (-6.021548), trying to recover @ x=Z_mass=104.328, coefList=(a0 = -3.9602 +/- 1.64079e-07,a1 = 0.0995964 +/- 3.95727e-06,a2 = -0.000596985 +/- 0.313786)
#      p.d.f value is less than zero (-23.663266), trying to recover @ x=Z_mass=109.884, coefList=(a0 = -3.9602 +/- 1.64079e-07,a1 = 0.0995964 +/- 3.95727e-06,a2 = -0.000596985 +/- 0.313786)
#      p.d.f value is less than zero (-1.565709), trying to recover @ x=Z_mass=102.56, coefList=(a0 = -3.9602 +/- 1.64079e-07,a1 = 0.0995964 +/- 3.95727e-06,a2 = -0.000596985 +/- 0.313786)
#      p.d.f value is less than zero (-2.574755), trying to recover @ x=Z_mass=102.98, coefList=(a0 = -3.9602 +/- 1.64079e-07,a1 = 0.0995964 +/- 3.95727e-06,a2 = -0.000596985 +/- 0.313786)
#      p.d.f value is less than zero (-0.631473), trying to recover @ x=Z_mass=102.16, coefList=(a0 = -3.9602 +/- 1.64079e-07,a1 = 0.0995964 +/- 3.95727e-06,a2 = -0.000596985 +/- 0.313786)
#      p.d.f value is less than zero (-0.105516), trying to recover @ x=Z_mass=101.93, coefList=(a0 = -3.9602 +/- 1.64079e-07,a1 = 0.0995964 +/- 3.95727e-06,a2 = -0.000596985 +/- 0.313786)
#      p.d.f value is less than zero (-13.217888), trying to recover @ x=Z_mass=106.816, coefList=(a0 = -3.9602 +/- 1.64079e-07,a1 = 0.0995964 +/- 3.95727e-06,a2 = -0.000596985 +/- 0.313786)
#      p.d.f value is less than zero (-14.432981), trying to recover @ x=Z_mass=107.201, coefList=(a0 = -3.9602 +/- 1.64079e-07,a1 = 0.0995964 +/- 3.95727e-06,a2 = -0.000596985 +/- 0.313786)
#      p.d.f value is less than zero (-12.581186), trying to recover @ x=Z_mass=106.61, coefList=(a0 = -3.9602 +/- 1.64079e-07,a1 = 0.0995964 +/- 3.95727e-06,a2 = -0.000596985 +/- 0.313786)
#      p.d.f value is less than zero (-17.694777), trying to recover @ x=Z_mass=108.195, coefList=(a0 = -3.9602 +/- 1.64079e-07,a1 = 0.0995964 +/- 3.95727e-06,a2 = -0.000596985 +/- 0.313786)
#      p.d.f value is less than zero (-5.472370), trying to recover @ x=Z_mass=104.121, coefList=(a0 = -3.9602 +/- 1.64079e-07,a1 = 0.0995964 +/- 3.95727e-06,a2 = -0.000596985 +/- 0.313786)
#      p.d.f value is less than zero (-5.155213), trying to recover @ x=Z_mass=104.001, coefList=(a0 = -3.9602 +/- 1.64079e-07,a1 = 0.0995964 +/- 3.95727e-06,a2 = -0.000596985 +/- 0.313786)
#     ... (remaining 3 messages suppressed)
# RooAddPdf::model[ nbkg * background + nsig * gaussian ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -6.02155/315.937,gaussian = 5.4196e-09/5.46411), !coefficients=(nbkg = 334.898 +/- 4.98263e-05,nsig = 1217.78 +/- 9.32502e-05)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -23.6633/315.937,gaussian = 3.12077e-17/5.46411), !coefficients=(nbkg = 334.898 +/- 4.98263e-05,nsig = 1217.78 +/- 9.32502e-05)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -1.56571/315.937,gaussian = 5.81722e-07/5.46411), !coefficients=(nbkg = 334.898 +/- 4.98263e-05,nsig = 1217.78 +/- 9.32502e-05)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -2.57475/315.937,gaussian = 2.03554e-07/5.46411), !coefficients=(nbkg = 334.898 +/- 4.98263e-05,nsig = 1217.78 +/- 9.32502e-05)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -0.631473/315.937,gaussian = 1.52904e-06/5.46411), !coefficients=(nbkg = 334.898 +/- 4.98263e-05,nsig = 1217.78 +/- 9.32502e-05)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -0.105516/315.937,gaussian = 2.62732e-06/5.46411), !coefficients=(nbkg = 334.898 +/- 4.98263e-05,nsig = 1217.78 +/- 9.32502e-05)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -13.2179/315.937,gaussian = 2.47455e-12/5.46411), !coefficients=(nbkg = 334.898 +/- 4.98263e-05,nsig = 1217.78 +/- 9.32502e-05)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -14.433/315.937,gaussian = 6.68885e-13/5.46411), !coefficients=(nbkg = 334.898 +/- 4.98263e-05,nsig = 1217.78 +/- 9.32502e-05)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -12.5812/315.937,gaussian = 4.90754e-12/5.46411), !coefficients=(nbkg = 334.898 +/- 4.98263e-05,nsig = 1217.78 +/- 9.32502e-05)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -17.6948/315.937,gaussian = 1.98169e-14/5.46411), !coefficients=(nbkg = 334.898 +/- 4.98263e-05,nsig = 1217.78 +/- 9.32502e-05)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -5.47237/315.937,gaussian = 9.69048e-09/5.46411), !coefficients=(nbkg = 334.898 +/- 4.98263e-05,nsig = 1217.78 +/- 9.32502e-05)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -5.15521/315.937,gaussian = 1.35478e-08/5.46411), !coefficients=(nbkg = 334.898 +/- 4.98263e-05,nsig = 1217.78 +/- 9.32502e-05)
#     ... (remaining 3 messages suppressed)
# RooNLLVar::nll_model_[ paramSet=(a0,a1,a2,mean,nbkg,nsig,sigma) ]
#      function value is NAN @ paramSet=(a0 = -3.9602 +/- 1.64079e-07,a1 = 0.0995964 +/- 3.95727e-06,a2 = -0.000596985 +/- 0.313786,mean = 90.879 +/- 1.72598e-07,nbkg = 334.898 +/- 4.98263e-05,nsig = 1217.78 +/- 9.32502e-05,sigma = 2.17986 +/- 6.98749e-08)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (13877) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	a0=-3.9602	a1=0.0995964	a2=-0.000589188	mean=90.879	nbkg=334.898	nsig=1217.78	sigma=2.17986
# RooPolynomial::background[ x=Z_mass coefList=(a0,a1,a2) ]
#      p.d.f value is less than zero (-13.317817), trying to recover @ x=Z_mass=109.884, coefList=(a0 = -3.9602 +/- 1.64079e-07,a1 = 0.0995964 +/- 3.95727e-06,a2 = -0.000589188 +/- 0.313786)
#      p.d.f value is less than zero (-3.715072), trying to recover @ x=Z_mass=106.816, coefList=(a0 = -3.9602 +/- 1.64079e-07,a1 = 0.0995964 +/- 3.95727e-06,a2 = -0.000589188 +/- 0.313786)
#      p.d.f value is less than zero (-4.826934), trying to recover @ x=Z_mass=107.201, coefList=(a0 = -3.9602 +/- 1.64079e-07,a1 = 0.0995964 +/- 3.95727e-06,a2 = -0.000589188 +/- 0.313786)
#      p.d.f value is less than zero (-3.133107), trying to recover @ x=Z_mass=106.61, coefList=(a0 = -3.9602 +/- 1.64079e-07,a1 = 0.0995964 +/- 3.95727e-06,a2 = -0.000589188 +/- 0.313786)
#      p.d.f value is less than zero (-7.818977), trying to recover @ x=Z_mass=108.195, coefList=(a0 = -3.9602 +/- 1.64079e-07,a1 = 0.0995964 +/- 3.95727e-06,a2 = -0.000589188 +/- 0.313786)
# RooAddPdf::model[ nbkg * background + nsig * gaussian ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -13.3178/554.535,gaussian = 3.12077e-17/5.46411), !coefficients=(nbkg = 334.898 +/- 4.98263e-05,nsig = 1217.78 +/- 9.32502e-05)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -3.71507/554.535,gaussian = 2.47455e-12/5.46411), !coefficients=(nbkg = 334.898 +/- 4.98263e-05,nsig = 1217.78 +/- 9.32502e-05)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -4.82693/554.535,gaussian = 6.68885e-13/5.46411), !coefficients=(nbkg = 334.898 +/- 4.98263e-05,nsig = 1217.78 +/- 9.32502e-05)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -3.13311/554.535,gaussian = 4.90754e-12/5.46411), !coefficients=(nbkg = 334.898 +/- 4.98263e-05,nsig = 1217.78 +/- 9.32502e-05)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -7.81898/554.535,gaussian = 1.98169e-14/5.46411), !coefficients=(nbkg = 334.898 +/- 4.98263e-05,nsig = 1217.78 +/- 9.32502e-05)
# RooNLLVar::nll_model_[ paramSet=(a0,a1,a2,mean,nbkg,nsig,sigma) ]
#      function value is NAN @ paramSet=(a0 = -3.9602 +/- 1.64079e-07,a1 = 0.0995964 +/- 3.95727e-06,a2 = -0.000589188 +/- 0.313786,mean = 90.879 +/- 1.72598e-07,nbkg = 334.898 +/- 4.98263e-05,nsig = 1217.78 +/- 9.32502e-05,sigma = 2.17986 +/- 6.98749e-08)
#
#  MINUIT WARNING IN HESSE
#  ============== Negative diagonal element 1 in Error Matrix
#  MINUIT WARNING IN HESSE
#  ============== Negative diagonal element 2 in Error Matrix
#  MINUIT WARNING IN HESSE
#  ============== 2.67835e+08 added to diagonal of error matrix
#  EIGENVALUES OF SECOND-DERIVATIVE MATRIX:
#         -1.2998e+05  9.9999e-01  1.0000e+00  1.0000e+00  1.0000e+00  1.0003e+00  1.2998e+05
#  MINUIT WARNING IN HESSE
#  ============== MATRIX FORCED POS-DEF BY ADDING 130112.177869 TO DIAGONAL.
#  FCN=-5578.63 FROM HESSE     STATUS=NOT POSDEF     58 CALLS         907 TOTAL
#                      EDM=1.09348e+08    STRATEGY= 1      ERR MATRIX NOT POS-DEF
#   EXT PARAMETER                APPROXIMATE     INTERNAL      INTERNAL
#   NO.   NAME      VALUE            ERROR       STEP SIZE       VALUE
#    1  a0          -3.96020e+00   1.55659e-06   5.84990e-05  -4.07178e-01
#    2  a1           9.95964e-02   6.19937e-01   6.59366e-07   9.95980e-03
#    3  a2          -5.75629e-04   2.08940e-06   1.35585e-07  -5.75629e-05
#    4  mean         9.08790e+01   1.68736e-06   7.49196e-05   8.80104e-02
#    5  nbkg         3.34898e+02   4.86858e-04   8.08332e-05  -1.33880e+00
#    6  nsig         1.21778e+03   9.11596e-04   7.02693e-05  -2.01587e+00
#    7  sigma        2.17986e+00   6.83170e-07   1.62805e-04  -2.52308e+00
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  7    ERR DEF=0.5
#   2.423e-12  3.502e-08  1.178e-13 -2.525e-16 -2.052e-13 -1.978e-13 -9.776e-17
#   3.502e-08  3.848e-01  1.295e-06 -2.775e-09 -2.255e-06 -2.174e-06 -1.074e-09
#   1.178e-13  1.295e-06  4.366e-12 -9.339e-15 -7.586e-12 -7.316e-12 -3.615e-15
#  -2.525e-16 -2.775e-09 -9.339e-15  2.847e-12  1.626e-14  1.568e-14  7.749e-18
#  -2.052e-13 -2.255e-06 -7.586e-12  1.626e-14  2.370e-07  1.274e-11  6.295e-15
#  -1.978e-13 -2.174e-06 -7.316e-12  1.568e-14  1.274e-11  8.310e-07  6.070e-15
#  -9.776e-17 -1.074e-09 -3.615e-15  7.749e-18  6.295e-15  6.070e-15  4.667e-13
# ERR MATRIX NOT POS-DEF
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2      3      4      5      6      7
#         1  0.03626   1.000  0.036  0.036 -0.000 -0.000 -0.000 -0.000
#         2  0.99900   0.036  1.000  0.999 -0.003 -0.007 -0.004 -0.003
#         3  0.99900   0.036  0.999  1.000 -0.003 -0.007 -0.004 -0.003
#         4  0.00265  -0.000 -0.003 -0.003  1.000  0.000  0.000  0.000
#         5  0.00747  -0.000 -0.007 -0.007  0.000  1.000  0.000  0.000
#         6  0.00384  -0.000 -0.004 -0.004  0.000  0.000  1.000  0.000
#         7  0.00254  -0.000 -0.003 -0.003  0.000  0.000  0.000  1.000
#  ERR MATRIX NOT POS-DEF
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(model) directly selected PDF components: (background)
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(model) indirectly selected PDF components: ()
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(model) directly selected PDF components: (gaussian)
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(model) indirectly selected PDF components: ()
# Info in <TCanvas::Print>: png file plots/MC/cuts_v6//fit_gauss_Z_both.png has been created

# %%
Y_candidates = ak.flatten(branches['Y_mass']).to_numpy()
Y_mass = ROOT.RooRealVar("Y_mass", "Y_mass", 7, 11, "GeV")
data = ROOT.RooDataSet.from_numpy({f"Y_mass": Y_candidates}, [Y_mass])

# frame = fit_unbinned_gauss_with_background(data, Y_mass, 40)
frame = fit_unbinned_double_gauss_Y(data, Y_mass, 40)

# Draw the frame on the canvas
canvas = ROOT.TCanvas("canvas", "Y Candidates")
frame.Draw()
canvas.Draw()
canvas.SaveAs(f"{savepath}/fit_dg_Y_{eleID_cut_type}.png")
# Out:
# [#0] WARNING:DataHandling -- RooDataSet.from_numpy() Ignored 8 out-of-range events
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (gaussian1,gaussian2)
#  **********
#  **    1 **SET PRINT           1
#  **********
#  **********
#  **    2 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 f_sig1       5.00000e-01  1.00000e-01    0.00000e+00  1.00000e+00
#      2 mean1        9.70000e+00  6.50000e-01    1.00000e+00  1.10000e+01
#      3 sigma1       1.00000e-01  4.50000e-02    1.00000e-02  1.00000e+01
#      4 sigma2       1.00000e-01  4.50000e-02    1.00000e-02  1.00000e+01
#  **********
#  **    3 **SET ERR         0.5
#  **********
#  **********
#  **    4 **SET PRINT           1
#  **********
#  **********
#  **    5 **SET STR           1
#  **********
#  NOW USING STRATEGY  1: TRY TO BALANCE SPEED AGAINST RELIABILITY
#  **********
#  **    6 **MIGRAD        2000           1
#  **********
#  FIRST CALL TO USER FUNCTION AT NEW START POINT, WITH IFLAG=4.
#  START MIGRAD MINIMIZATION.  STRATEGY  1.  CONVERGENCE WHEN EDM .LT. 1.00e-03
#  FCN=18939.3 FROM MIGRAD    STATUS=INITIATE      149 CALLS         150 TOTAL
#                      EDM= unknown      STRATEGY= 1      NO ERROR MATRIX
#   EXT PARAMETER               CURRENT GUESS       STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  f_sig1       5.67448e-01   1.00000e-01   0.00000e+00   0.00000e+00
#    2  mean1        9.70000e+00   6.50000e-01   0.00000e+00   1.77746e+05
#    3  sigma1       1.00000e-01   4.50000e-02   0.00000e+00  -2.17514e+05
#    4  sigma2       1.00000e-01   4.50000e-02   0.00000e+00  -1.65807e+05
#                                ERR DEF= 0.5
#  MIGRAD FAILS TO FIND IMPROVEMENT
#  MINUIT WARNING IN HESSE
#  ============== Negative diagonal element 4 in Error Matrix
#  MINUIT WARNING IN HESSE
#  ============== 1682.86 added to diagonal of error matrix
#  EIGENVALUES OF SECOND-DERIVATIVE MATRIX:
#         -2.3181e+01  6.4430e-01  1.8834e+00  2.4653e+01
#  MINUIT WARNING IN HESSE
#  ============== MATRIX FORCED POS-DEF BY ADDING 23.205265 TO DIAGONAL.
#  FCN=1068.92 FROM HESSE     STATUS=NOT POSDEF     25 CALLS         207 TOTAL
#                      EDM=1.11905e+06    STRATEGY= 1      ERR MATRIX NOT POS-DEF
#   EXT PARAMETER                APPROXIMATE        STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  f_sig1       5.67448e-01   2.68392e-02   5.00000e-03  -2.97151e+02
#    2  mean1        9.18050e+00   1.08963e-02   5.93424e-05  -1.05960e+04
#    3  sigma1       2.43511e-01   2.34132e-02   1.30067e-01   2.02282e+03
#    4  sigma2       1.52269e+00   5.39730e+00   9.91474e-02  -3.51163e+02
#                                ERR DEF= 0.5
#  MIGRAD FAILS TO FIND IMPROVEMENT
#  MIGRAD TERMINATED WITHOUT CONVERGENCE.
#  FCN=1068.92 FROM MIGRAD    STATUS=FAILED        217 CALLS         218 TOTAL
#                      EDM=1.11905e+06    STRATEGY= 1      ERR MATRIX NOT POS-DEF
#   EXT PARAMETER                APPROXIMATE        STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  f_sig1       5.67448e-01   2.68392e-02  -0.00000e+00  -2.97151e+02
#    2  mean1        9.18050e+00   1.08963e-02  -0.00000e+00  -1.05960e+04
#    3  sigma1       2.43511e-01   2.34132e-02   0.00000e+00   2.02282e+03
#    4  sigma2       1.52269e+00   5.39730e+00   0.00000e+00  -3.51163e+02
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  4    ERR DEF=0.5
#   7.210e-04  2.865e-04 -6.258e-04 -4.293e-01
#   2.865e-04  1.187e-04 -2.501e-04 -1.716e-01
#  -6.258e-04 -2.501e-04  5.482e-04  3.749e-01
#  -4.293e-01 -1.716e-01  3.749e-01  2.572e+02
# ERR MATRIX NOT POS-DEF
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2      3      4
#         1  0.99679   1.000  0.979 -0.995 -0.997
#         2  0.98216   0.979  1.000 -0.980 -0.982
#         3  0.99841  -0.995 -0.980  1.000  0.998
#         4  0.99897  -0.997 -0.982  0.998  1.000
#  ERR MATRIX NOT POS-DEF
#  **********
#  **    7 **SET ERR         0.5
#  **********
#  **********
#  **    8 **SET PRINT           1
#  **********
#  **********
#  **    9 **HESSE        2000
#  **********
#  MINUIT WARNING IN HESSE
#  ============== Negative diagonal element 4 in Error Matrix
#  MINUIT WARNING IN HESSE
#  ============== 1679.46 added to diagonal of error matrix
#  EIGENVALUES OF SECOND-DERIVATIVE MATRIX:
#         -2.0490e+01  6.4499e-01  1.8737e+00  2.1972e+01
#  MINUIT WARNING IN HESSE
#  ============== MATRIX FORCED POS-DEF BY ADDING 20.512371 TO DIAGONAL.
#  FCN=1068.92 FROM HESSE     STATUS=NOT POSDEF     27 CALLS         245 TOTAL
#                      EDM=2.50761e+06    STRATEGY= 1      ERR MATRIX NOT POS-DEF
#   EXT PARAMETER                APPROXIMATE     INTERNAL      INTERNAL
#   NO.   NAME      VALUE            ERROR       STEP SIZE       VALUE
#    1  f_sig1       5.67448e-01   2.81606e-02   7.06892e-04   1.35309e-01
#    2  mean1        9.18050e+00   1.15361e-02   1.18685e-05   6.89434e-01
#    3  sigma1       2.43511e-01   2.49524e-02   1.30067e-01   2.72770e+05
#    4  sigma2       1.52269e+00   5.09350e+00   4.95737e-02   2.07927e+05
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  4    ERR DEF=0.5
#   7.939e-04  3.182e-04 -6.998e-04 -4.768e-01
#   3.182e-04  1.331e-04 -2.822e-04 -1.923e-01
#  -6.998e-04 -2.822e-04  6.227e-04  4.230e-01
#  -4.768e-01 -1.923e-01  4.230e-01  2.882e+02
# ERR MATRIX NOT POS-DEF
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2      3      4
#         1  0.99671   1.000  0.979 -0.995 -0.997
#         2  0.98209   0.979  1.000 -0.980 -0.982
#         3  0.99842  -0.995 -0.980  1.000  0.998
#         4  0.99897  -0.997 -0.982  0.998  1.000
#  ERR MATRIX NOT POS-DEF
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#0] ERROR:Plotting -- RooAbsPdf::plotOn(model) ERROR: component selection expression 'background_model' does not select any components of p.d.f.
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(model) directly selected PDF components: (gaussian1)
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(model) indirectly selected PDF components: ()
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(model) directly selected PDF components: (gaussian2)
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(model) indirectly selected PDF components: ()
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TCanvas::Print>: png file plots/MC/cuts_v6//fit_dg_Y_both.png has been created
