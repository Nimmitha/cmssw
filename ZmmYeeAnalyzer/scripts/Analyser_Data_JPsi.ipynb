# %%
import uproot as up
import numpy as np
import awkward as ak
import mplhep as hep
hep.style.use(hep.style.CMS)
import ROOT
import matplotlib.pyplot as plt
from fit_types import fit_unbinned_gauss_with_background_J
# Out:
# Welcome to JupyROOT 6.26/10

# %%
dataset = '../output/ZmmYee/Data/crab_TTree_13TeV_fourmuon_Run2UL_v6.root'
savepath = 'plots/Data/cuts_JPsi/'
# dataset = '../output/ZmmYee/MC/ZmmMCOut.root'
# savepath = 'plots/MC/cuts_temp/'

# %%
# open the file
file = up.open(dataset)
events = file['ntuple;1']
columns = ['Event', 'Run', 'LumiBlock',
           'Mu_TriggerPath',
           'Z_soft1', 'Z_soft2',
           'Z_Vtx_Mass', 'Z_mass',
           'Z_pt1', 'Z_pt2', 'Z_eta1', 'Z_eta2',
           'Z_lowPt', 'Z_highPt',
           'Y_Vtx_Mass', 'Y_mass',
           'Y_pt1', 'Y_pt2', 'Y_eta1', 'Y_eta2',
           'Y_mvaIsoWP90_1', 'Y_mvaIsoWP90_2',
           'Z_Vtx_Prob', 'Y_Vtx_Prob',
           'FourL_mass', 'FourL_Vtx_Prob',
           'Y_lowPt', 'Y_highPt']
# branches = events.arrays(columns, entry_start=430, entry_stop=450)
branches = events.arrays(columns)

# %%
def print_summary(data, text):
    events = len(data)
    candidates = np.sum(ak.num(branches['Y_mass'], axis=1))

    print(f"Number of candidates {text}: {candidates}")
    print(f"Number of events {text}: {events}")

# %%
print_summary(branches, 'Preselection')
# Out:
# Number of candidates Preselection: 1151437
# Number of events Preselection: 854885

# %%
print(ak.sum(branches.Y_pt1 > branches.Y_pt2))
print(ak.sum(branches.Z_pt1 > branches.Z_pt2))
print(ak.sum(branches.Z_lowPt < branches.Z_highPt))

# remove events with Z_pt1 < Z_pt2
cut_highLow_candi= (branches.Z_pt1 > branches.Z_pt2)
cut_highLow_events = ak.any(cut_highLow_candi, axis=1)

branches = branches[cut_highLow_candi][cut_highLow_events]

cut_highLow_candi_Y = (branches.Y_pt1 > branches.Y_pt2)
cut_highLow_events_Y = ak.any(cut_highLow_candi_Y, axis=1)

branches = branches[cut_highLow_candi_Y][cut_highLow_events_Y]

print_summary(branches, 'Z pt1 > Z pt2')
# Out:
# 1151437
# 1151228
# 1151437
# Number of candidates Z pt1 > Z pt2: 1151228
# Number of events Z pt1 > Z pt2: 854771

# %%
cut_YTrigger_candi = branches['Mu_TriggerPath']
cut_YTrigger_event = ak.any(cut_YTrigger_candi, axis=1)

branches = branches[cut_YTrigger_candi][cut_YTrigger_event]

print_summary(branches, "Trigger")
# Out:
# Number of candidates Trigger: 606377
# Number of events Trigger: 506981

# %%
cut_Zsoft_candi = branches['Z_soft1'] & branches['Z_soft2']
cut_Zsoft_event = ak.any(cut_Zsoft_candi, axis=1)

branches = branches[cut_Zsoft_candi][cut_Zsoft_event]

print_summary(branches, "Soft Muons")
# Out:
# Number of candidates Soft Muons: 504452
# Number of events Soft Muons: 440559

# %%
# events with hights pt muon > 24
cut_highPt24_candi = branches['Z_highPt'] > 24
cut_highPt24_event = ak.any(cut_highPt24_candi, axis=1)

branches = branches[cut_highPt24_candi][cut_highPt24_event]

print_summary(branches, "High Pt Muon")
# Out:
# Number of candidates High Pt Muon: 503509
# Number of events High Pt Muon: 440012

# %%
cut_dilepton_candi = (branches['Y_Vtx_Prob'] > 0.01) & (branches['Z_Vtx_Prob'] > 0.01)
cut_dilepton_event = ak.any(cut_dilepton_candi, axis=1)

plt.figure(figsize=(8, 8))
nbins, xlow, xhigh = 100, 0, 1
plt.hist(ak.flatten(branches.Y_Vtx_Prob), bins=nbins, label="Y", alpha=0.5)
plt.hist(ak.flatten(branches.Z_Vtx_Prob), bins=nbins, label="Z", alpha=0.5)
plt.axvline(x=0.01, color='r')
plt.xlabel('Dilepton Vtx Prob')
plt.ylabel(f"Counts / {(xhigh-xlow)/nbins:.2f}")
plt.legend()
plt.tight_layout()
plt.savefig(f"{savepath}/vtx_prob_dilepton.png")

branches = branches[cut_dilepton_candi][cut_dilepton_event]

print_summary(branches, "Dilepton Vtx")
# Out:
# Number of candidates Dilepton Vtx: 452211
# Number of events Dilepton Vtx: 397475

# %%
cut_FourL_candi = (branches['FourL_Vtx_Prob'] > 0.01)
cut_FourL_event = ak.any(cut_FourL_candi, axis=1)

plt.figure(figsize=(8, 8))
nbins, xlow, xhigh = 100, 0, 1
plt.hist(ak.flatten(branches.FourL_Vtx_Prob), bins=nbins, alpha=0.5)
plt.axvline(x=0.01, color='r')
plt.xlabel('FourL Vtx Prob')
plt.ylabel(f"Counts / {(xhigh-xlow)/nbins:.2f}")
plt.tight_layout()
plt.savefig(f"{savepath}/vtx_prob_fourL.png")

branches = branches[cut_FourL_candi][cut_FourL_event]

print_summary(branches, "FourL Vtx")
# Out:
# Number of candidates FourL Vtx: 413905
# Number of events FourL Vtx: 365331

# %%
cut_Pt_candi = (branches['Z_pt1'] > 3.0) & (branches['Z_pt2'] > 3.0) & (branches['Y_pt1'] > 5.0) & (branches['Y_pt2'] > 5.0)
cut_eta_candi = (abs(branches['Z_eta1']) < 2.4) & (abs(branches['Z_eta2']) < 2.4) & (abs(branches['Y_eta1']) < 2.5) & (abs(branches['Y_eta2']) < 2.5)
cut_detector_candi = cut_Pt_candi & cut_eta_candi
cut_detector_event = ak.any(cut_detector_candi, axis=1)

plt.figure(figsize=(8, 8))
nbins, xlow, xhigh = 75, 0, 150
plt.hist(ak.flatten(branches.Z_pt1), bins=nbins, label="Mu_pt1", range=(xlow, xhigh), alpha=0.5) #, histtype='step')
plt.hist(ak.flatten(branches.Z_pt2), bins=nbins, label="Mu_pt2", range=(xlow, xhigh), alpha=0.5) #, histtype='step')
plt.axvline(3.0, color='r')
plt.xlabel("Mu pT [GeV]")
plt.ylabel(f"Counts / {(xhigh-xlow)/nbins:.2f} GeV")
plt.legend()
plt.tight_layout()
plt.savefig(f"{savepath}/Mu_pt.png")

plt.figure(figsize=(8, 8))
nbins, xlow, xhigh = 50, 0, 50
plt.hist(ak.flatten(branches.Y_pt1), bins=nbins, label="Ele_pt1", range=(xlow, xhigh), alpha=0.5) #, histtype='step')
plt.hist(ak.flatten(branches.Y_pt2), bins=nbins, label="Ele_pt2", range=(xlow, xhigh), alpha=0.5) #, histtype='step')
plt.axvline(5.0, color='r')
plt.xlabel("Ele pT [GeV]")
plt.ylabel(f"Counts / {(xhigh-xlow)/nbins:.2f} GeV")
plt.legend()
plt.tight_layout()
plt.savefig(f"{savepath}/Ele_pt.png")

plt.figure(figsize=(8, 8))
nbins, xlow, xhigh = 30, -3, 3
plt.hist(ak.flatten(branches.Z_eta1), bins=nbins, label="Mu_eta1", range=(xlow, xhigh), alpha=0.5) #, histtype='step')
plt.hist(ak.flatten(branches.Z_eta2), bins=nbins, label="Mu_eta2", range=(xlow, xhigh), alpha=0.5) #, histtype='step')
plt.axvline(2.4, color='r')
plt.xlabel("Mu eta")
plt.ylabel(f"Counts / {(xhigh-xlow)/nbins:.2f}")
plt.legend()
plt.tight_layout()
plt.savefig(f"{savepath}/Mu_eta.png")

plt.figure(figsize=(8, 8))
nbins, xlow, xhigh = 30, -3, 3
plt.hist(ak.flatten(branches.Y_eta1), bins=nbins, label="Ele_eta1", range=(xlow, xhigh), alpha=0.5) #, histtype='step')
plt.hist(ak.flatten(branches.Y_eta2), bins=nbins, label="Ele_eta2", range=(xlow, xhigh), alpha=0.5) #, histtype='step')
plt.axvline(2.5, color='r')
plt.xlabel("Ele eta")
plt.ylabel(f"Counts / {(xhigh-xlow)/nbins:.2f}")
plt.legend()
plt.tight_layout()
plt.savefig(f"{savepath}/Ele_eta.png")

# plt.figure(figsize=(8, 8))
# plt.plot(ak.flatten(branches.Y_eta1), ak.flatten(branches.Y_pt1), '.', label='Ele1')
# plt.xlim(-3, 3)
# plt.legend()
# plt.xlabel('Ele eta')
# plt.ylabel('Ele pT')
# plt.tight_layout()

# plt.figure(figsize=(8, 8))
# plt.plot(ak.flatten(branches.Y_eta2), ak.flatten(branches.Y_pt2), '.', label='Ele2')
# plt.xlim(-3, 3)
# plt.legend()
# plt.xlabel('Ele eta')
# plt.ylabel('Ele pT')
# plt.tight_layout()

branches = branches[cut_detector_candi][cut_detector_event]

# draw a 2D histogram of the eta and pt of the electrons
plt.figure(figsize=(8, 8))
eta = ak.flatten(branches.Y_eta1).tolist()
pt = ak.flatten(branches.Y_pt1).tolist()
plt.hist2d(eta, pt, bins=(50, 50), range=((-3, 3), (0, 50)))
plt.colorbar()
plt.xlabel('Ele1 eta')
plt.ylabel('Ele1 pT')
plt.tight_layout()
plt.savefig(f"{savepath}/Ele1_eta_pt.png")

plt.figure(figsize=(8, 8))
eta = ak.flatten(branches.Y_eta2).tolist()
pt = ak.flatten(branches.Y_pt2).tolist()
plt.hist2d(eta, pt, bins=(50, 25), range=((-3, 3), (0, 25)))
plt.colorbar()
plt.xlabel('Ele2 eta')
plt.ylabel('Ele2 pT')
plt.tight_layout()
plt.savefig(f"{savepath}/Ele2_eta_pt.png")

print_summary(branches, "Detector")
# Out:
# Number of candidates Detector: 105336
# Number of events Detector: 98464

# %%
plt.figure(figsize=(8, 8))
nbins, xlow, xhigh = 50, 0, 5

mean_Ymass = np.mean(ak.flatten(branches.Y_mass))
std_Ymass = np.std(ak.flatten(branches.Y_mass))
mean_Yvtxmass = np.mean(ak.flatten(branches.Y_Vtx_Mass))
std_Yvtxmass = np.std(ak.flatten(branches.Y_Vtx_Mass))

plt.hist(ak.flatten(branches.Y_Vtx_Mass), bins=nbins, label=f"diele_Vtx_Mass ({mean_Yvtxmass:.1f}+/-{std_Yvtxmass:.1f})", alpha=0.5, range=(xlow, xhigh))
plt.hist(ak.flatten(branches.Y_mass), bins=nbins, label=f"diele_mass ({mean_Ymass:.1f}+/-{std_Ymass:.1f})", alpha=0.5, range=(xlow, xhigh))

plt.legend(fontsize=12)
plt.xlabel('Dielectron inv mass (GeV)')
plt.ylabel(f"Counts / {(xhigh-xlow)/nbins:.2f} GeV")
plt.tight_layout()
plt.savefig(f"{savepath}/Vtx_vs_normal_mass_Y.png")

plt.figure(figsize=(8, 8))
nbins, xlow, xhigh = 50, 65, 115

mean_Zmass = np.mean(ak.flatten(branches.Z_mass))
std_Zmass = np.std(ak.flatten(branches.Z_mass))
mean_Zvtxmass = np.mean(ak.flatten(branches.Z_Vtx_Mass))
std_Zvtxmass = np.std(ak.flatten(branches.Z_Vtx_Mass))

plt.hist(ak.flatten(branches.Z_Vtx_Mass), bins=nbins, label=f"dimu_Vtx_Mass ({mean_Zvtxmass:.1f}+/-{std_Zvtxmass:.1f})", alpha=0.5, range=(xlow, xhigh))
plt.hist(ak.flatten(branches.Z_mass), bins=nbins, label=f"dimu_mass ({mean_Zmass:.1f}+/-{std_Zmass:.1f})", alpha=0.5, range=(xlow, xhigh))

plt.legend(fontsize=12)
plt.xlabel('Dimuon inv mass (GeV)')
plt.ylabel(f"Counts / {(xhigh-xlow)/nbins:.2f} GeV")
plt.tight_layout()
plt.savefig(f"{savepath}/Vtx_vs_normal_mass_Z.png")

# %%
before_mass_cuts_Y = ak.flatten(branches['Y_mass'])
Hpt_before_mass_cuts_Y = ak.flatten(branches['Y_pt1'])
Lpt_before_mass_cuts_Y = ak.flatten(branches['Y_pt2'])

before_mass_cuts_Z = ak.flatten(branches['Z_mass'])
Hpt_before_mass_cuts_Z = ak.flatten(branches['Z_pt1'])
Lpt_before_mass_cuts_Z = ak.flatten(branches['Z_pt2'])

# %%
# cut_Ymass_candi = (branches['Y_mass'] > 2) & (branches['Y_mass'] < 4)
# cut_Ymass_event = ak.any(cut_Ymass_candi, axis=1)

# plt.figure(figsize=(8, 8))
# nbins, xlow, xhigh = 20, 1, 5
# plt.hist(ak.flatten(branches.Y_mass), bins=nbins, label="Y_mass", alpha=0.5, range=(xlow, xhigh))
# mean = np.mean(ak.flatten(branches.Y_mass))
# std = np.std(ak.flatten(branches.Y_mass))
# plt.text(0.75, 0.9, f"Mean: {mean:.2f}\nStd: {std:.2f}", transform=plt.gca().transAxes, fontsize=12)
# plt.text(0.75, 0.85, f"Events: {len(ak.flatten(branches.Y_mass))}", transform=plt.gca().transAxes, fontsize=12)
# plt.axvline(x=2, color='r')
# plt.axvline(x=4, color='r')
# plt.xlabel('Dielectron inv mass (GeV)')
# plt.ylabel(f"Counts / {(xhigh-xlow)/nbins:.2f} GeV")
# plt.tight_layout()
# plt.savefig(f"{savepath}/Y_mass_cut.png")

# branches = branches[cut_Ymass_candi][cut_Ymass_event]

# print_summary(branches, "Y mass")

# %%
cut_Zmass_candi = (branches['Z_mass'] > 70) & (branches['Z_mass'] < 110)
cut_Zmass_event = ak.any(cut_Zmass_candi, axis=1)

plt.figure(figsize=(8, 8))
nbins, xlow, xhigh = 20, 70, 110
plt.hist(ak.flatten(branches.Z_mass), bins=nbins, label="Z_mass", alpha=0.5, range=(xlow, xhigh))
mean = np.mean(ak.flatten(branches.Z_mass))
std = np.std(ak.flatten(branches.Z_mass))
plt.text(0.8, 0.9, f"Mean: {mean:.2f}\nStd: {std:.2f}", transform=plt.gca().transAxes, fontsize=12)
plt.text(0.8, 0.85, f"Events: {len(ak.flatten(branches.Z_mass))}", transform=plt.gca().transAxes, fontsize=12)
plt.xlabel('Dimuon inv Mass (GeV)')
plt.ylabel(f"Counts / {(xhigh-xlow)/nbins:.2f} GeV")
plt.tight_layout()
plt.savefig(f"{savepath}/Z_mass_cut.png")

branches = branches[cut_Zmass_candi][cut_Zmass_event]

print_summary(branches, "Z mass")
# Out:
# Number of candidates Z mass: 87116
# Number of events Z mass: 82518

# %%
before_ID_cuts_Y = ak.flatten(branches['Y_mass'])
Hpt_before_ID_cuts_Y = ak.flatten(branches['Y_pt1'])
Lpt_before_ID_cuts_Y = ak.flatten(branches['Y_pt2'])

before_ID_cuts_Z = ak.flatten(branches['Z_mass'])
Hpt_before_ID_cuts_Z = ak.flatten(branches['Z_pt1'])
Lpt_before_ID_cuts_Z = ak.flatten(branches['Z_pt2'])

eleID_cut_type = "both" # "low pT", "high pT", "both"
print(eleID_cut_type)

if eleID_cut_type == "low pT":
    cut_YmvaIso_candi = branches['Y_mvaIsoWP90_2']
elif eleID_cut_type == "high pT":
    cut_YmvaIso_candi = branches['Y_mvaIsoWP90_1']
elif eleID_cut_type == "both":
    cut_YmvaIso_candi = branches['Y_mvaIsoWP90_1'] & branches['Y_mvaIsoWP90_2']
else:
    print("Invalid eleID_cut_type")

cut_YmvaIso_event = ak.any(cut_YmvaIso_candi, axis=1)

branches = branches[cut_YmvaIso_candi][cut_YmvaIso_event]

print_summary(branches, "YmvaIso")
# Out:
# both
# Number of candidates YmvaIso: 713
# Number of events YmvaIso: 710

# %%
before_trig_cut_Y = ak.flatten(branches['Y_mass'])
Hpt_before_trig_cut_Y = ak.flatten(branches['Y_pt1'])
Lpt_before_trig_cut_Y = ak.flatten(branches['Y_pt2'])

before_trig_cut_Z = ak.flatten(branches['Z_mass'])
Hpt_before_trig_cut_Z = ak.flatten(branches['Z_pt1'])
Lpt_before_trig_cut_Z = ak.flatten(branches['Z_pt2'])

# %%
# cut_FourLmass_candi = (branches['FourL_mass'] > 112) & (branches['FourL_mass'] < 162)
# cut_FourLmass_event = ak.any(cut_FourLmass_candi, axis=1)

# plt.figure(figsize=(8, 8))
# nbins, xlow, xhigh = 35, 100, 170
# plt.hist(ak.flatten(branches.FourL_mass), bins=nbins, label="FourL_mass", alpha=0.5, range=(xlow, xhigh))
# mean = np.mean(ak.flatten(branches.FourL_mass))
# std = np.std(ak.flatten(branches.FourL_mass))
# plt.text(0.75, 0.9, f"Mean: {mean:.2f}\nStd: {std:.2f}", transform=plt.gca().transAxes, fontsize=12)
# plt.text(0.75, 0.85, f"Events: {len(ak.flatten(branches.FourL_mass))}", transform=plt.gca().transAxes, fontsize=12)
# plt.xlabel('FourL inv mass (GeV)')
# plt.ylabel(f"Counts / {(xhigh-xlow)/nbins:.2f} GeV")
# plt.axline((112, 0), (112, 100), color='r')
# plt.axline((162, 0), (162, 100), color='r')
# plt.tight_layout()
# plt.savefig(f"{savepath}/FourL_mass.png")

# branches = branches[cut_FourLmass_candi][cut_FourLmass_event]

# print_summary(branches, "FourL mass")

# %% [markdown]
# ## Plotting cut steps

# %%
plt.figure(figsize=(8, 8))
nbins, xlow, xhigh = 60, 2, 4

plt.hist(before_ID_cuts_Y, bins=nbins, label="Acceptance cut", alpha=0.5, range=(xlow, xhigh))
plt.hist(before_trig_cut_Y, bins=nbins, label=f"WP90 {eleID_cut_type}", alpha=0.5, range=(xlow, xhigh))
plt.xlabel('Dielectron inv mass (GeV)')
plt.ylabel(f"Counts / {(xhigh-xlow)/nbins:.2f} GeV")
plt.legend()
plt.yscale('log')
plt.tight_layout()
plt.savefig(f"{savepath}/Y_mass_dist_for {eleID_cut_type} cuts.png")

# %%
plt.figure(figsize=(8, 8))
nbins, xlow, xhigh = 30, 70, 110

plt.hist(before_mass_cuts_Z, bins=nbins, label="Acceptance cuts", alpha=0.5, range=(xlow, xhigh))
# plt.hist(before_ID_cuts_Z, bins=nbins, label="Mass cut", alpha=0.5, range=(xlow, xhigh))
plt.hist(before_trig_cut_Z, bins=nbins, label=f"WP90 {eleID_cut_type}", alpha=0.5, range=(xlow, xhigh))
plt.xlabel('Dimuon inv mass (GeV)')
plt.ylabel(f"Counts / {(xhigh-xlow)/nbins:.2f} GeV")
plt.legend()
plt.tight_layout()
plt.savefig(f"{savepath}/Z_mass_dist_for {eleID_cut_type} cuts.png")

# %%
plt.figure(figsize=(8, 8))
nbins, xlow, xhigh = 40, 5, 45

plt.hist(Hpt_before_mass_cuts_Y, bins=nbins, label="Acceptance cut", alpha=0.5, range=(xlow, xhigh))
# plt.hist(Hpt_before_ID_cuts_Y, bins=nbins, label="Mass", alpha=0.5, range=(xlow, xhigh))
plt.hist(Hpt_before_trig_cut_Y, bins=nbins, label=f"WP90 {eleID_cut_type}", alpha=0.5, range=(xlow, xhigh))
plt.xlabel('High pT electron (GeV)')
plt.ylabel(f"Counts / {(xhigh-xlow)/nbins:.2f} GeV")
plt.legend()
plt.tight_layout()
plt.savefig(f"{savepath}/Y_highPt_dist_for {eleID_cut_type} cuts.png")

plt.figure(figsize=(8, 8))
nbins, xlow, xhigh = 30, 5, 20

plt.hist(Lpt_before_mass_cuts_Y, bins=nbins, label="Acceptance cut", alpha=0.5, range=(xlow, xhigh))
# plt.hist(Lpt_before_ID_cuts_Y, bins=nbins, label="Mass", alpha=0.5, range=(xlow, xhigh))
plt.hist(Lpt_before_trig_cut_Y, bins=nbins, label=f"WP90 {eleID_cut_type}", alpha=0.5, range=(xlow, xhigh))
plt.xlabel('Low pT electron (GeV)')
plt.ylabel(f"Counts / {(xhigh-xlow)/nbins:.2f} GeV")
plt.legend()
plt.tight_layout()
plt.savefig(f"{savepath}/Y_lowPt_dist_for {eleID_cut_type} cuts.png")

# %%
plt.figure(figsize=(8, 8))
nbins, xlow, xhigh = 30, 20, 150

plt.hist(Hpt_before_mass_cuts_Z, bins=nbins, label="Acceptance cuts", alpha=0.5, range=(xlow, xhigh))
# plt.hist(Hpt_before_ID_cuts_Z, bins=nbins, label="Mass cut", alpha=0.5, range=(xlow, xhigh))
plt.hist(Hpt_before_trig_cut_Z, bins=nbins, label=f"WP90 {eleID_cut_type}", alpha=0.5, range=(xlow, xhigh))
plt.xlabel('High pT Muon (GeV)')
plt.ylabel(f"Counts / {(xhigh-xlow)/nbins:.2f} GeV")
plt.legend()
plt.tight_layout()
plt.savefig(f"{savepath}/Z_highPt_dist_for {eleID_cut_type} cuts.png")

plt.figure(figsize=(8, 8))
nbins, xlow, xhigh = 30, 0, 100

plt.hist(Lpt_before_mass_cuts_Z, bins=nbins, label="Acceptance cuts", alpha=0.5, range=(xlow, xhigh))
# plt.hist(Lpt_before_ID_cuts_Z, bins=nbins, label="Mass cut", alpha=0.5, range=(xlow, xhigh))
plt.hist(Lpt_before_trig_cut_Z, bins=nbins, label=f"WP90 {eleID_cut_type}", alpha=0.5, range=(xlow, xhigh))
plt.xlabel('Low pT Muon (GeV)')
plt.ylabel(f"Counts / {(xhigh-xlow)/nbins:.2f} GeV")
plt.legend()
plt.tight_layout()
plt.savefig(f"{savepath}/Z_lowPt_dist_for {eleID_cut_type} cuts.png")

# %%
# highestPt_muon = ak.argmax(branches.Z_highPt, axis=1, keepdims=True, mask_identity=True)

# cut_ZtrackIso_candi = (branches['Z_trackIso1'][highestPt_muon] < 0.35) & (branches['Z_trackIso2'][highestPt_muon] < 0.35)
# cut_ZtrackIso_event = ak.any(cut_ZtrackIso_candi, axis=1)

# plt.hist(ak.flatten(branches.Z_trackIso1[highestPt_muon]), bins=100, range=(0, 2), label="Z_trackIso1", alpha=0.5)
# plt.hist(ak.flatten(branches.Z_trackIso2[highestPt_muon]), bins=100, range=(0, 2), label="Z_trackIso2", alpha=0.5)
# plt.axvline(x=0.35, color='r')
# plt.xlabel('Z_trackIso')
# # plt.xlim([0,1])
# plt.legend()

# branches = branches[cut_ZtrackIso_candi][cut_ZtrackIso_event]

# print_summary(branches, "ZTrackIso")

# %% [markdown]
# ## Fitting

# %%
plt.figure(figsize=(8, 8))
nbins, xlow, xhigh = 20, 2, 4
plt.hist(ak.flatten(branches.Y_mass), bins=nbins, label="Y_mass", alpha=0.5, range=(xlow, xhigh))

# show mean and std on plot
mean = np.mean(ak.flatten(branches.Y_mass))
std = np.std(ak.flatten(branches.Y_mass))
plt.text(0.8, 0.9, f"Mean: {mean:.2f}\nStd: {std:.2f}", transform=plt.gca().transAxes, fontsize=12)
plt.text(0.8, 0.85, f"Events: {len(ak.flatten(branches.Y_mass))}", transform=plt.gca().transAxes, fontsize=12)

plt.xlabel('Dielectron inv mass (GeV)')
plt.ylabel(f"Counts / {(xhigh-xlow)/nbins:.2f} GeV")
plt.tight_layout()
plt.savefig(f"{savepath}/fit_histogram_Y_{eleID_cut_type}.png")

plt.figure(figsize=(8, 8))
nbins, xlow, xhigh = 20, 70, 110
plt.hist(ak.flatten(branches.Z_mass), bins=nbins, label="Z_mass", alpha=0.5, range=(xlow, xhigh))

# show mean and std on plot
mean = np.mean(ak.flatten(branches.Z_mass))
std = np.std(ak.flatten(branches.Z_mass))
plt.text(0.8, 0.9, f"Mean: {mean:.2f}\nStd: {std:.2f}", transform=plt.gca().transAxes, fontsize=12)
plt.text(0.8, 0.85, f"Events: {len(ak.flatten(branches.Z_mass))}", transform=plt.gca().transAxes, fontsize=12)

plt.xlabel('Dimuon inv mass (GeV)')
plt.ylabel(f"Counts / {(xhigh-xlow)/nbins:.2f} GeV")
plt.tight_layout()
plt.savefig(f"{savepath}/fit_histogram_Z_{eleID_cut_type}.png")

# %%
# Z_candidates = ak.flatten(branches['Z_mass']).to_numpy()
# Z_mass = ROOT.RooRealVar("Z_mass", "Z_mass", 70, 110, "GeV")
# data = ROOT.RooDataSet.from_numpy({f"Z_mass": Z_candidates}, [Z_mass])

# frame = fit_unbinned_gauss_with_background(data, Z_mass, 20)

# # Draw the frame on the canvas
# canvas = ROOT.TCanvas("canvas", "Z Candidates")
# frame.Draw()
# canvas.Draw()
# canvas.SaveAs(f"{savepath}/fit_gauss_Z_{eleID_cut_type}.png")

# %%
Y_candidates = ak.flatten(branches['Y_mass']).to_numpy()
Y_mass = ROOT.RooRealVar("Y_mass", "Y_mass", 1, 5, "GeV")
data = ROOT.RooDataSet.from_numpy({f"Y_mass": Y_candidates}, [Y_mass])

frame = fit_unbinned_gauss_with_background_J(data, Y_mass, 20)

# Draw the frame on the canvas
canvas = ROOT.TCanvas("canvas", "Y Candidates")
frame.Draw()
canvas.Draw()
canvas.SaveAs(f"{savepath}/fit_dg_Y_{eleID_cut_type}.png")
# Out:
# [#0] WARNING:DataHandling -- RooDataSet.from_numpy() Ignored 446 out-of-range events
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (background,gaussian)
#  **********
#  **    1 **SET PRINT           1
#  **********
#  **********
#  **    2 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 a0           1.00000e-01  2.00000e+00   -1.00000e+01  1.00000e+01
#      2 a1           1.00000e-01  2.00000e+00   -1.00000e+01  1.00000e+01
#      3 a2           1.00000e-01  2.00000e+00   -1.00000e+01  1.00000e+01
#      4 mean         3.00000e+00  4.00000e-01    1.00000e+00  5.00000e+00
#      5 nbkg         1.00000e+04  2.50000e+03    0.00000e+00  2.50000e+04
#      6 nsig         1.50000e+04  2.50000e+03    0.00000e+00  2.50000e+04
#      7 sigma        1.00000e-02  4.50000e-03    1.00000e-03  1.50000e-01
#  **********
#  **    3 **SET ERR         0.5
#  **********
#  **********
#  **    4 **SET PRINT           1
#  **********
#  **********
#  **    5 **SET STR           1
#  **********
#  NOW USING STRATEGY  1: TRY TO BALANCE SPEED AGAINST RELIABILITY
#  **********
#  **    6 **MIGRAD        3500           1
#  **********
#  FIRST CALL TO USER FUNCTION AT NEW START POINT, WITH IFLAG=4.
#  START MIGRAD MINIMIZATION.  STRATEGY  1.  CONVERGENCE WHEN EDM .LT. 1.00e-03
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (23047) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	a0=0.1	a1=0.1	a2=-0.0491145	mean=3	nbkg=10000	nsig=15000	sigma=0.01
# RooAddPdf::model[ nbkg * background + nsig * gaussian ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -1.95675/1.67147,gaussian = 0/0.0250663), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -0.680623/1.67147,gaussian = 0/0.0250663), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -0.409993/1.67147,gaussian = 0/0.0250663), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -2.11721/1.67147,gaussian = 0/0.0250663), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -1.27467/1.67147,gaussian = 0/0.0250663), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -0.685869/1.67147,gaussian = 0/0.0250663), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -1.02774/1.67147,gaussian = 0/0.0250663), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -2.09575/1.67147,gaussian = 0/0.0250663), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -1.45116/1.67147,gaussian = 0/0.0250663), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -0.726518/1.67147,gaussian = 0/0.0250663), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -0.660596/1.67147,gaussian = 0/0.0250663), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -1.35269/1.67147,gaussian = 0/0.0250663), !coefficients=(nbkg = 10000,nsig = 15000)
#     ... (remaining 22 messages suppressed)
# RooNLLVar::nll_model_[ paramSet=(a0,a1,a2,mean,nbkg,nsig,sigma) ]
#      function value is NAN @ paramSet=(a0 = 0.1,a1 = 0.1,a2 = -0.0491145,mean = 3,nbkg = 10000,nsig = 15000,sigma = 0.01)
# RooPolynomial::background[ x=Y_mass coefList=(a0,a1,a2) ]
#      p.d.f value is less than zero (-1.956754), trying to recover @ x=Y_mass=4.92807, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.0491145)
#      p.d.f value is less than zero (-0.680623), trying to recover @ x=Y_mass=4.3307, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.0491145)
#      p.d.f value is less than zero (-0.409993), trying to recover @ x=Y_mass=4.17276, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.0491145)
#      p.d.f value is less than zero (-2.117211), trying to recover @ x=Y_mass=4.99143, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.0491145)
#      p.d.f value is less than zero (-1.274674), trying to recover @ x=Y_mass=4.6331, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.0491145)
#      p.d.f value is less than zero (-0.685869), trying to recover @ x=Y_mass=4.33362, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.0491145)
#      p.d.f value is less than zero (-1.027741), trying to recover @ x=Y_mass=4.51365, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.0491145)
#      p.d.f value is less than zero (-2.095753), trying to recover @ x=Y_mass=4.98307, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.0491145)
#      p.d.f value is less than zero (-1.451157), trying to recover @ x=Y_mass=4.71392, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.0491145)
#      p.d.f value is less than zero (-0.726518), trying to recover @ x=Y_mass=4.35604, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.0491145)
#      p.d.f value is less than zero (-0.660596), trying to recover @ x=Y_mass=4.31952, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.0491145)
#      p.d.f value is less than zero (-1.352689), trying to recover @ x=Y_mass=4.66926, coefList=(a0 = 0.1,a1 = 0.1,a2 = -0.0491145)
#     ... (remaining 22 messages suppressed)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (23185.6) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	a0=0.1	a1=-0.570712	a2=0.1	mean=3	nbkg=10000	nsig=15000	sigma=0.01
# RooAddPdf::model[ nbkg * background + nsig * gaussian ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -1.34955/-2.78942,gaussian = 0/0.0250663), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = 0.399758/-2.78942,gaussian = 0/0.0250663), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = 0.603835/-2.78942,gaussian = 0/0.0250663), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -0.921104/-2.78942,gaussian = 6.10163e-198/0.0250663), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = 0.366615/-2.78942,gaussian = 0/0.0250663), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -1.22076/-2.78942,gaussian = 1.11761e-47/0.0250663), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -0.00836264/-2.78942,gaussian = 0/0.0250663), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = 0.559484/-2.78942,gaussian = 0/0.0250663), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -1.05115/-2.78942,gaussian = 1.94415e-36/0.0250663), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -0.399181/-2.78942,gaussian = 0/0.0250663), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -1.1484/-2.78942,gaussian = 0/0.0250663), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -1.25434/-2.78942,gaussian = 0/0.0250663), !coefficients=(nbkg = 10000,nsig = 15000)
#     ... (remaining 257 messages suppressed)
# RooNLLVar::nll_model_[ paramSet=(a0,a1,a2,mean,nbkg,nsig,sigma) ]
#      function value is NAN @ paramSet=(a0 = 0.1,a1 = -0.570712,a2 = 0.1,mean = 3,nbkg = 10000,nsig = 15000,sigma = 0.01)
# RooPolynomial::background[ x=Y_mass coefList=(a0,a1,a2) ]
#      p.d.f normalization integral is zero or negative: -2.789424 @ x=Y_mass=3.48176, coefList=(a0 = 0.1,a1 = -0.570712,a2 = 0.1)
#      p.d.f normalization integral is zero or negative: -2.789424 @ x=Y_mass=1.28334, coefList=(a0 = 0.1,a1 = -0.570712,a2 = 0.1)
#      p.d.f normalization integral is zero or negative: -2.789424 @ x=Y_mass=1.03392, coefList=(a0 = 0.1,a1 = -0.570712,a2 = 0.1)
#      p.d.f normalization integral is zero or negative: -2.789424 @ x=Y_mass=2.69864, coefList=(a0 = 0.1,a1 = -0.570712,a2 = 0.1)
#      p.d.f normalization integral is zero or negative: -2.789424 @ x=Y_mass=1.3211, coefList=(a0 = 0.1,a1 = -0.570712,a2 = 0.1)
#      p.d.f normalization integral is zero or negative: -2.789424 @ x=Y_mass=3.14704, coefList=(a0 = 0.1,a1 = -0.570712,a2 = 0.1)
#      p.d.f normalization integral is zero or negative: -2.789424 @ x=Y_mass=1.72083, coefList=(a0 = 0.1,a1 = -0.570712,a2 = 0.1)
#      p.d.f normalization integral is zero or negative: -2.789424 @ x=Y_mass=1.09121, coefList=(a0 = 0.1,a1 = -0.570712,a2 = 0.1)
#      p.d.f normalization integral is zero or negative: -2.789424 @ x=Y_mass=2.87176, coefList=(a0 = 0.1,a1 = -0.570712,a2 = 0.1)
#      p.d.f normalization integral is zero or negative: -2.789424 @ x=Y_mass=4.92807, coefList=(a0 = 0.1,a1 = -0.570712,a2 = 0.1)
#      p.d.f normalization integral is zero or negative: -2.789424 @ x=Y_mass=4.3307, coefList=(a0 = 0.1,a1 = -0.570712,a2 = 0.1)
#      p.d.f normalization integral is zero or negative: -2.789424 @ x=Y_mass=4.17276, coefList=(a0 = 0.1,a1 = -0.570712,a2 = 0.1)
#     ... (remaining 257 messages suppressed)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (23185.6) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	a0=0.1	a1=-0.569967	a2=0.1	mean=3	nbkg=10000	nsig=15000	sigma=0.01
# RooAddPdf::model[ nbkg * background + nsig * gaussian ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -1.34052/-2.75866,gaussian = 0/0.0250663), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = 0.400984/-2.75866,gaussian = 0/0.0250663), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = 0.604631/-2.75866,gaussian = 0/0.0250663), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -0.915683/-2.75866,gaussian = 6.10163e-198/0.0250663), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = 0.367914/-2.75866,gaussian = 0/0.0250663), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -1.21339/-2.75866,gaussian = 1.11761e-47/0.0250663), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -0.00615836/-2.75866,gaussian = 0/0.0250663), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = 0.560371/-2.75866,gaussian = 0/0.0250663), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -1.04501/-2.75866,gaussian = 1.94415e-36/0.0250663), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -0.381104/-2.75866,gaussian = 0/0.0250663), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -1.13444/-2.75866,gaussian = 0/0.0250663), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -1.24137/-2.75866,gaussian = 0/0.0250663), !coefficients=(nbkg = 10000,nsig = 15000)
#     ... (remaining 257 messages suppressed)
# RooNLLVar::nll_model_[ paramSet=(a0,a1,a2,mean,nbkg,nsig,sigma) ]
#      function value is NAN @ paramSet=(a0 = 0.1,a1 = -0.569967,a2 = 0.1,mean = 3,nbkg = 10000,nsig = 15000,sigma = 0.01)
# RooPolynomial::background[ x=Y_mass coefList=(a0,a1,a2) ]
#      p.d.f normalization integral is zero or negative: -2.758656 @ x=Y_mass=3.48176, coefList=(a0 = 0.1,a1 = -0.569967,a2 = 0.1)
#      p.d.f normalization integral is zero or negative: -2.758656 @ x=Y_mass=1.28334, coefList=(a0 = 0.1,a1 = -0.569967,a2 = 0.1)
#      p.d.f normalization integral is zero or negative: -2.758656 @ x=Y_mass=1.03392, coefList=(a0 = 0.1,a1 = -0.569967,a2 = 0.1)
#      p.d.f normalization integral is zero or negative: -2.758656 @ x=Y_mass=2.69864, coefList=(a0 = 0.1,a1 = -0.569967,a2 = 0.1)
#      p.d.f normalization integral is zero or negative: -2.758656 @ x=Y_mass=1.3211, coefList=(a0 = 0.1,a1 = -0.569967,a2 = 0.1)
#      p.d.f normalization integral is zero or negative: -2.758656 @ x=Y_mass=3.14704, coefList=(a0 = 0.1,a1 = -0.569967,a2 = 0.1)
#      p.d.f normalization integral is zero or negative: -2.758656 @ x=Y_mass=1.72083, coefList=(a0 = 0.1,a1 = -0.569967,a2 = 0.1)
#      p.d.f normalization integral is zero or negative: -2.758656 @ x=Y_mass=1.09121, coefList=(a0 = 0.1,a1 = -0.569967,a2 = 0.1)
#      p.d.f normalization integral is zero or negative: -2.758656 @ x=Y_mass=2.87176, coefList=(a0 = 0.1,a1 = -0.569967,a2 = 0.1)
#      p.d.f normalization integral is zero or negative: -2.758656 @ x=Y_mass=4.92807, coefList=(a0 = 0.1,a1 = -0.569967,a2 = 0.1)
#      p.d.f normalization integral is zero or negative: -2.758656 @ x=Y_mass=4.3307, coefList=(a0 = 0.1,a1 = -0.569967,a2 = 0.1)
#      p.d.f normalization integral is zero or negative: -2.758656 @ x=Y_mass=4.17276, coefList=(a0 = 0.1,a1 = -0.569967,a2 = 0.1)
#     ... (remaining 257 messages suppressed)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (23185.6) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	a0=0.1	a1=-0.458651	a2=0.1	mean=3	nbkg=10000	nsig=15000	sigma=0.01
# RooAddPdf::model[ nbkg * background + nsig * gaussian ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -0.105007/1.84242,gaussian = 6.10163e-198/0.0250663), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -0.110927/1.84242,gaussian = 1.11761e-47/0.0250663), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -0.12698/1.84242,gaussian = 1.94415e-36/0.0250663), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -0.122094/1.84242,gaussian = 6.38402e-12/0.0250663), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -0.0964515/1.84242,gaussian = 6.85888e-100/0.0250663), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -0.106125/1.84242,gaussian = 2.92607e-190/0.0250663), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -0.053739/1.84242,gaussian = 0/0.0250663), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -0.129181/1.84242,gaussian = 2.70812e-08/0.0250663), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -0.068766/1.84242,gaussian = 9.1018e-205/0.0250663), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -0.104937/1.84242,gaussian = 7.36293e-69/0.0250663), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -0.0791869/1.84242,gaussian = 0/0.0250663), !coefficients=(nbkg = 10000,nsig = 15000)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -0.128675/1.84242,gaussian = 0.111322/0.0250663), !coefficients=(nbkg = 10000,nsig = 15000)
#     ... (remaining 81 messages suppressed)
# RooNLLVar::nll_model_[ paramSet=(a0,a1,a2,mean,nbkg,nsig,sigma) ]
#      function value is NAN @ paramSet=(a0 = 0.1,a1 = -0.458651,a2 = 0.1,mean = 3,nbkg = 10000,nsig = 15000,sigma = 0.01)
# RooPolynomial::background[ x=Y_mass coefList=(a0,a1,a2) ]
#      p.d.f value is less than zero (-0.105007), trying to recover @ x=Y_mass=2.69864, coefList=(a0 = 0.1,a1 = -0.458651,a2 = 0.1)
#      p.d.f value is less than zero (-0.110927), trying to recover @ x=Y_mass=3.14704, coefList=(a0 = 0.1,a1 = -0.458651,a2 = 0.1)
#      p.d.f value is less than zero (-0.126980), trying to recover @ x=Y_mass=2.87176, coefList=(a0 = 0.1,a1 = -0.458651,a2 = 0.1)
#      p.d.f value is less than zero (-0.122094), trying to recover @ x=Y_mass=3.0718, coefList=(a0 = 0.1,a1 = -0.458651,a2 = 0.1)
#      p.d.f value is less than zero (-0.096452), trying to recover @ x=Y_mass=3.2137, coefList=(a0 = 0.1,a1 = -0.458651,a2 = 0.1)
#      p.d.f value is less than zero (-0.106125), trying to recover @ x=Y_mass=2.70456, coefList=(a0 = 0.1,a1 = -0.458651,a2 = 0.1)
#      p.d.f value is less than zero (-0.053739), trying to recover @ x=Y_mass=2.49896, coefList=(a0 = 0.1,a1 = -0.458651,a2 = 0.1)
#      p.d.f value is less than zero (-0.129181), trying to recover @ x=Y_mass=2.94097, coefList=(a0 = 0.1,a1 = -0.458651,a2 = 0.1)
#      p.d.f value is less than zero (-0.068766), trying to recover @ x=Y_mass=3.30654, coefList=(a0 = 0.1,a1 = -0.458651,a2 = 0.1)
#      p.d.f value is less than zero (-0.104937), trying to recover @ x=Y_mass=3.17713, coefList=(a0 = 0.1,a1 = -0.458651,a2 = 0.1)
#      p.d.f value is less than zero (-0.079187), trying to recover @ x=Y_mass=2.58587, coefList=(a0 = 0.1,a1 = -0.458651,a2 = 0.1)
#      p.d.f value is less than zero (-0.128675), trying to recover @ x=Y_mass=2.97905, coefList=(a0 = 0.1,a1 = -0.458651,a2 = 0.1)
#     ... (remaining 81 messages suppressed)
#
#  FCN=8011.68 FROM MIGRAD    STATUS=INITIATE      160 CALLS         161 TOTAL
#                      EDM= unknown      STRATEGY= 1      NO ERROR MATRIX
#   EXT PARAMETER               CURRENT GUESS       STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  a0           1.00000e-01   2.00000e+00   0.00000e+00  -5.45775e+03
#    2  a1          -3.47278e-01   2.00000e+00   0.00000e+00  -9.15705e+03
#    3  a2           7.66911e-02   2.00000e+00   0.00000e+00  -3.75041e+02
#    4  mean         3.01263e+00   4.00000e-01   0.00000e+00   4.02274e+00
#    5  nbkg         1.00000e+04   2.50000e+03   0.00000e+00   1.19205e+04
#    6  nsig         1.68932e-01   2.50000e+03   0.00000e+00   3.59846e+01
#    7  sigma        4.55489e-03   4.50000e-03  -1.86463e-01   7.57950e-03
#                                ERR DEF= 0.5
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (23185.6) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	a0=0.204464	a1=-0.345414	a2=0.0568044	mean=3.04166	nbkg=205.627	nsig=147.302	sigma=0.138546
# RooAddPdf::model[ nbkg * background + nsig * gaussian ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -0.0778293/1.03794,gaussian = 0.00643963/0.347283), !coefficients=(nbkg = 205.627,nsig = 147.302)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -0.0070064/1.03794,gaussian = 0.748779/0.347283), !coefficients=(nbkg = 205.627,nsig = 147.302)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -0.0339737/1.03794,gaussian = 3.36089e-15/0.347283), !coefficients=(nbkg = 205.627,nsig = 147.302)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -0.0932013/1.03794,gaussian = 6.72196e-05/0.347283), !coefficients=(nbkg = 205.627,nsig = 147.302)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -0.0786859/1.03794,gaussian = 0.00555194/0.347283), !coefficients=(nbkg = 205.627,nsig = 147.302)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -0.0249276/1.03794,gaussian = 0.462557/0.347283), !coefficients=(nbkg = 205.627,nsig = 147.302)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -0.0874118/1.03794,gaussian = 0.000774535/0.347283), !coefficients=(nbkg = 205.627,nsig = 147.302)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -0.0921653/1.03794,gaussian = 8.09898e-08/0.347283), !coefficients=(nbkg = 205.627,nsig = 147.302)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -0.0468728/1.03794,gaussian = 0.1608/0.347283), !coefficients=(nbkg = 205.627,nsig = 147.302)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -0.0153127/1.03794,gaussian = 0.619962/0.347283), !coefficients=(nbkg = 205.627,nsig = 147.302)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -0.00576994/1.03794,gaussian = 0.766597/0.347283), !coefficients=(nbkg = 205.627,nsig = 147.302)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -0.0725567/1.03794,gaussian = 0.0143992/0.347283), !coefficients=(nbkg = 205.627,nsig = 147.302)
#     ... (remaining 49 messages suppressed)
# RooNLLVar::nll_model_[ paramSet=(a0,a1,a2,mean,nbkg,nsig,sigma) ]
#      function value is NAN @ paramSet=(a0 = 0.204464,a1 = -0.345414,a2 = 0.0568044,mean = 3.04166,nbkg = 205.627,nsig = 147.302,sigma = 0.138546)
# RooPolynomial::background[ x=Y_mass coefList=(a0,a1,a2) ]
#      p.d.f value is less than zero (-0.077829), trying to recover @ x=Y_mass=3.48176, coefList=(a0 = 0.204464,a1 = -0.345414,a2 = 0.0568044)
#      p.d.f value is less than zero (-0.007006), trying to recover @ x=Y_mass=3.14704, coefList=(a0 = 0.204464,a1 = -0.345414,a2 = 0.0568044)
#      p.d.f value is less than zero (-0.033974), trying to recover @ x=Y_mass=4.17276, coefList=(a0 = 0.204464,a1 = -0.345414,a2 = 0.0568044)
#      p.d.f value is less than zero (-0.093201), trying to recover @ x=Y_mass=3.64897, coefList=(a0 = 0.204464,a1 = -0.345414,a2 = 0.0568044)
#      p.d.f value is less than zero (-0.078686), trying to recover @ x=Y_mass=3.48818, coefList=(a0 = 0.204464,a1 = -0.345414,a2 = 0.0568044)
#      p.d.f value is less than zero (-0.024928), trying to recover @ x=Y_mass=3.2137, coefList=(a0 = 0.204464,a1 = -0.345414,a2 = 0.0568044)
#      p.d.f value is less than zero (-0.087412), trying to recover @ x=Y_mass=3.56606, coefList=(a0 = 0.204464,a1 = -0.345414,a2 = 0.0568044)
#      p.d.f value is less than zero (-0.092165), trying to recover @ x=Y_mass=3.83341, coefList=(a0 = 0.204464,a1 = -0.345414,a2 = 0.0568044)
#      p.d.f value is less than zero (-0.046873), trying to recover @ x=Y_mass=3.30654, coefList=(a0 = 0.204464,a1 = -0.345414,a2 = 0.0568044)
#      p.d.f value is less than zero (-0.015313), trying to recover @ x=Y_mass=3.17713, coefList=(a0 = 0.204464,a1 = -0.345414,a2 = 0.0568044)
#      p.d.f value is less than zero (-0.005770), trying to recover @ x=Y_mass=3.14267, coefList=(a0 = 0.204464,a1 = -0.345414,a2 = 0.0568044)
#      p.d.f value is less than zero (-0.072557), trying to recover @ x=Y_mass=3.44514, coefList=(a0 = 0.204464,a1 = -0.345414,a2 = 0.0568044)
#     ... (remaining 49 messages suppressed)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (23185.6) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	a0=0.200708	a1=-0.344814	a2=0.0581547	mean=3.04017	nbkg=205.068	nsig=136.649	sigma=0.144186
# RooAddPdf::model[ nbkg * background + nsig * gaussian ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -0.0266389/1.22832,gaussian = 0.0091879/0.361422), !coefficients=(nbkg = 205.068,nsig = 136.649)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -0.0333112/1.22832,gaussian = 0.000134473/0.361422), !coefficients=(nbkg = 205.068,nsig = 136.649)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -0.0271768/1.22832,gaussian = 0.00800832/0.361422), !coefficients=(nbkg = 205.068,nsig = 136.649)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -0.0319406/1.22832,gaussian = 0.0012922/0.361422), !coefficients=(nbkg = 205.068,nsig = 136.649)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -0.0216807/1.22832,gaussian = 2.6776e-07/0.361422), !coefficients=(nbkg = 205.068,nsig = 136.649)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -0.00391686/1.22832,gaussian = 0.18151/0.361422), !coefficients=(nbkg = 205.068,nsig = 136.649)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -0.0231605/1.22832,gaussian = 0.0193653/0.361422), !coefficients=(nbkg = 205.068,nsig = 136.649)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -0.0297319/1.22832,gaussian = 6.02143e-06/0.361422), !coefficients=(nbkg = 205.068,nsig = 136.649)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -0.0323423/1.22832,gaussian = 3.28779e-05/0.361422), !coefficients=(nbkg = 205.068,nsig = 136.649)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -0.0331922/1.22832,gaussian = 9.63817e-05/0.361422), !coefficients=(nbkg = 205.068,nsig = 136.649)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -0.0318342/1.22832,gaussian = 2.16343e-05/0.361422), !coefficients=(nbkg = 205.068,nsig = 136.649)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(background = -0.0318899/1.22832,gaussian = 2.25704e-05/0.361422), !coefficients=(nbkg = 205.068,nsig = 136.649)
#     ... (remaining 25 messages suppressed)
# RooNLLVar::nll_model_[ paramSet=(a0,a1,a2,mean,nbkg,nsig,sigma) ]
#      function value is NAN @ paramSet=(a0 = 0.200708,a1 = -0.344814,a2 = 0.0581547,mean = 3.04017,nbkg = 205.068,nsig = 136.649,sigma = 0.144186)
# RooPolynomial::background[ x=Y_mass coefList=(a0,a1,a2) ]
#      p.d.f value is less than zero (-0.026639), trying to recover @ x=Y_mass=3.48176, coefList=(a0 = 0.200708,a1 = -0.344814,a2 = 0.0581547)
#      p.d.f value is less than zero (-0.033311), trying to recover @ x=Y_mass=3.64897, coefList=(a0 = 0.200708,a1 = -0.344814,a2 = 0.0581547)
#      p.d.f value is less than zero (-0.027177), trying to recover @ x=Y_mass=3.48818, coefList=(a0 = 0.200708,a1 = -0.344814,a2 = 0.0581547)
#      p.d.f value is less than zero (-0.031941), trying to recover @ x=Y_mass=3.56606, coefList=(a0 = 0.200708,a1 = -0.344814,a2 = 0.0581547)
#      p.d.f value is less than zero (-0.021681), trying to recover @ x=Y_mass=3.83341, coefList=(a0 = 0.200708,a1 = -0.344814,a2 = 0.0581547)
#      p.d.f value is less than zero (-0.003917), trying to recover @ x=Y_mass=3.30654, coefList=(a0 = 0.200708,a1 = -0.344814,a2 = 0.0581547)
#      p.d.f value is less than zero (-0.023160), trying to recover @ x=Y_mass=3.44514, coefList=(a0 = 0.200708,a1 = -0.344814,a2 = 0.0581547)
#      p.d.f value is less than zero (-0.029732), trying to recover @ x=Y_mass=3.74713, coefList=(a0 = 0.200708,a1 = -0.344814,a2 = 0.0581547)
#      p.d.f value is less than zero (-0.032342), trying to recover @ x=Y_mass=3.69531, coefList=(a0 = 0.200708,a1 = -0.344814,a2 = 0.0581547)
#      p.d.f value is less than zero (-0.033192), trying to recover @ x=Y_mass=3.66024, coefList=(a0 = 0.200708,a1 = -0.344814,a2 = 0.0581547)
#      p.d.f value is less than zero (-0.031834), trying to recover @ x=Y_mass=3.70846, coefList=(a0 = 0.200708,a1 = -0.344814,a2 = 0.0581547)
#      p.d.f value is less than zero (-0.031890), trying to recover @ x=Y_mass=3.70714, coefList=(a0 = 0.200708,a1 = -0.344814,a2 = 0.0581547)
#     ... (remaining 25 messages suppressed)
#
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  COVARIANCE MATRIX CALCULATED SUCCESSFULLY
#  FCN=-879.555 FROM HESSE     STATUS=OK             50 CALLS         638 TOTAL
#                      EDM=0.00129415    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  a0           4.50034e-01   9.87637e-02   3.96548e-05   1.78148e+00
#    2  a1          -2.96240e-01   3.10225e-02   8.12159e-06  -1.22524e+01
#    3  a2           3.69646e-02   4.63991e-03   1.73191e-06  -1.14886e+01
#    4  mean         3.07974e+00   3.69340e-02   3.76224e-04   6.96335e-01
#    5  nbkg         2.41311e+02   1.68849e+01   1.33608e-04   2.13506e-01
#    6  nsig         2.56729e+01   8.33880e+00   1.79766e-04   1.47630e-01
#    7  sigma        1.09634e-01   3.69906e-02   1.02168e-02  -1.35133e-02
#                                ERR DEF= 0.5
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  COVARIANCE MATRIX CALCULATED SUCCESSFULLY
#  FCN=-879.968 FROM MIGRAD    STATUS=CONVERGED     853 CALLS         854 TOTAL
#                      EDM=2.90011e-05    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  a0          -2.62888e-01   5.42815e-02   2.20350e-05  -2.20772e+00
#    2  a1           9.09224e-03   1.68833e-02   4.48659e-06  -7.76122e+00
#    3  a2           2.49416e-03   2.53521e-03   9.48839e-07  -2.45677e+01
#    4  mean         3.07665e+00   3.75106e-02   3.82214e-04   1.19849e-01
#    5  nbkg         2.40084e+02   1.71171e+01   1.33765e-04   5.25985e-02
#    6  nsig         2.69133e+01   8.93824e+00   1.77556e-04   6.99552e-02
#    7  sigma        1.13861e-01   4.23805e-02   1.21734e-02   1.84377e-03
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  7    ERR DEF=0.5
#   2.947e-03 -6.481e-04  1.336e-05  5.648e-06 -1.207e-01 -1.207e-01  5.006e-04
#  -6.481e-04  2.850e-04 -3.256e-05 -6.489e-06  1.202e-03  1.202e-03 -4.934e-06
#   1.336e-05 -3.256e-05  6.427e-06  4.784e-07  4.833e-03  4.834e-03 -2.005e-05
#   5.648e-06 -6.489e-06  4.784e-07  1.407e-03 -1.739e-02 -1.741e-02  1.440e-04
#  -1.207e-01  1.202e-03  4.833e-03 -1.739e-02  2.930e+02  5.294e+01 -2.244e-01
#  -1.207e-01  1.202e-03  4.834e-03 -1.741e-02  5.294e+01  7.990e+01 -2.246e-01
#   5.006e-04 -4.934e-06 -2.005e-05  1.440e-04 -2.244e-01 -2.246e-01  2.148e-03
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2      3      4      5      6      7
#         1  0.98043   1.000 -0.707  0.097  0.003 -0.130 -0.249  0.199
#         2  0.99167  -0.707  1.000 -0.761 -0.010  0.004  0.008 -0.006
#         3  0.98343   0.097 -0.761  1.000  0.005  0.111  0.213 -0.171
#         4  0.09667   0.003 -0.010  0.005  1.000 -0.027 -0.052  0.083
#         5  0.36786  -0.130  0.004  0.111 -0.027  1.000  0.346 -0.283
#         6  0.60637  -0.249  0.008  0.213 -0.052  0.346  1.000 -0.542
#         7  0.56148   0.199 -0.006 -0.171  0.083 -0.283 -0.542  1.000
#  **********
#  **    7 **SET ERR         0.5
#  **********
#  **********
#  **    8 **SET PRINT           1
#  **********
#  **********
#  **    9 **HESSE        3500
#  **********
#  COVARIANCE MATRIX CALCULATED SUCCESSFULLY
#  FCN=-879.968 FROM HESSE     STATUS=OK             50 CALLS         904 TOTAL
#                      EDM=3.45786e-05    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                INTERNAL      INTERNAL
#   NO.   NAME      VALUE            ERROR       STEP SIZE       VALUE
#    1  a0          -2.62888e-01   9.55709e-02   4.40700e-06  -2.62918e-02
#    2  a1           9.09224e-03   3.70335e-02   8.97319e-07   9.09224e-04
#    3  a2           2.49416e-03   4.61630e-03   1.89768e-07   2.49416e-04
#    4  mean         3.07665e+00   3.75342e-02   7.64429e-05   3.83332e-02
#    5  nbkg         2.40084e+02   1.71800e+01   2.67531e-05  -1.76710e+00
#    6  nsig         2.69133e+01   9.05560e+00   3.55112e-05  -1.50516e+00
#    7  sigma        1.13861e-01   4.26261e-02   4.86936e-04   2.60068e+00
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  7    ERR DEF=0.5
#   9.134e-03 -3.153e-03  2.812e-04  5.418e-05 -1.685e-01 -1.685e-01  6.946e-04
#  -3.153e-03  1.371e-03 -1.564e-04 -2.734e-05  7.965e-03  7.965e-03 -3.287e-05
#   2.812e-04 -1.564e-04  2.131e-05  2.839e-06  5.446e-03  5.446e-03 -2.243e-05
#   5.418e-05 -2.734e-05  2.839e-06  1.409e-03 -1.791e-02 -1.792e-02  1.539e-04
#  -1.685e-01  7.965e-03  5.446e-03 -1.791e-02  2.952e+02  5.508e+01 -2.320e-01
#  -1.685e-01  7.965e-03  5.446e-03 -1.792e-02  5.508e+01  8.201e+01 -2.320e-01
#   6.946e-04 -3.287e-05 -2.243e-05  1.539e-04 -2.320e-01 -2.320e-01  2.178e-03
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2      3      4      5      6      7
#         1  0.99373   1.000 -0.891  0.637  0.015 -0.103 -0.195  0.156
#         2  0.99827  -0.891  1.000 -0.915 -0.020  0.013  0.024 -0.019
#         3  0.99503   0.637 -0.915  1.000  0.016  0.069  0.130 -0.104
#         4  0.10294   0.015 -0.020  0.016  1.000 -0.028 -0.053  0.088
#         5  0.37635  -0.103  0.013  0.069 -0.028  1.000  0.354 -0.289
#         6  0.61965  -0.195  0.024  0.130 -0.053  0.354  1.000 -0.549
#         7  0.56978   0.156 -0.019 -0.104  0.088 -0.289 -0.549  1.000
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(model) directly selected PDF components: (background)
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(model) indirectly selected PDF components: ()
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(model) directly selected PDF components: (gaussian)
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(model) indirectly selected PDF components: ()
# Info in <TCanvas::Print>: png file plots/Data/cuts_JPsi//fit_dg_Y_both.png has been created
