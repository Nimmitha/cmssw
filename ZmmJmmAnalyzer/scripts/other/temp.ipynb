# %%
import uproot as up
import awkward as ak
import matplotlib.pyplot as plt

# %%
file = '/uscms/home/wkarunar/nobackup/analysis/run3/jmm_counting/CMSSW_14_1_5/src/ZmmJmmAnalyzer/preselection/parkingDoubleMuonLowMass/2024/crab_TTree_136TeV_PDMLM0_mm_2024H_Run385986.root'
tree = up.open(file)['ntuple']

# %%
tree.show()
# Out:
# name                 | typename                 | interpretation
# ---------------------+--------------------------+-------------------------------
# nB                   | uint32_t                 | AsDtype('>u4')
# Run                  | float                    | AsDtype('>f4')
# LumiBlock            | float                    | AsDtype('>f4')
# Event                | float                    | AsDtype('>f4')
# TriggerFired         | bool                     | AsDtype('bool')
# B_J1_mass            | float                    | AsDtype('>f4')
# B_J1_px              | float                    | AsDtype('>f4')
# B_J1_py              | float                    | AsDtype('>f4')
# B_J1_pz              | float                    | AsDtype('>f4')
# B_J1_pt              | float                    | AsDtype('>f4')
# B_J1_eta             | float                    | AsDtype('>f4')
# B_J1_phi             | float                    | AsDtype('>f4')
# ...

# %%
branches_to_read = ["B_J1_mass", "B_J1_VtxMass", "B_J1_VtxProb"]

# %%
arrays = tree.arrays(branches_to_read, library='np')

# %%
ak_array = ak.Array(arrays)

# %%
# Write to ROOT file
with up.recreate("output.root") as f:
    f["ntuple"] = ak_array
